# %% [markdown]
# # Deep Learning
# ## Assignment 4
#
# Previously in 2_fullyconnected.ipynb and 3_regularization.ipynb, we trained fully connected networks to classify notMNIST characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range
# Out:
# /home/raf/anaconda3/envs/TensorFlow/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /home/raf/anaconda3/envs/TensorFlow/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
#
# * convolutions need the image data formatted as a cube (width by height by #channels)
# * labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.479287
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.715554
# Minibatch accuracy: 37.5%
# Validation accuracy: 55.1%
# Minibatch loss at step 100: 1.099864
# Minibatch accuracy: 68.8%
# Validation accuracy: 68.5%
# Minibatch loss at step 150: 0.391970
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.0%
# Minibatch loss at step 200: 0.796921
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.9%
# Minibatch loss at step 250: 0.665195
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.3%
# Minibatch loss at step 300: 0.578133
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.0%
# Minibatch loss at step 350: 0.848842
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.4%
# Minibatch loss at step 400: 0.517794
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 450: 0.587518
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 500: 0.980571
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 550: 1.194607
# Minibatch accuracy: 62.5%
# Validation accuracy: 81.3%
# Minibatch loss at step 600: 0.903601
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.0%
# Minibatch loss at step 650: 0.521549
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 700: 0.910991
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.4%
# Minibatch loss at step 750: 0.442654
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 800: 0.517425
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 850: 0.109164
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 900: 0.561259
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 950: 1.020084
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 1000: 0.242103
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.1%
# Test accuracy: 89.7%

# %% [markdown]
# ## Problem 1
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (nn.max_pool()) of stride 2 and kernel size 2.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

  def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1], padding='SAME')
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    conv = maxpool2d(conv, k=2)
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
    conv = maxpool2d(conv, k=2)
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.600600
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.108762
# Minibatch accuracy: 31.2%
# Validation accuracy: 34.1%
# Minibatch loss at step 100: 1.582662
# Minibatch accuracy: 25.0%
# Validation accuracy: 58.1%
# Minibatch loss at step 150: 0.591690
# Minibatch accuracy: 75.0%
# Validation accuracy: 71.4%
# Minibatch loss at step 200: 0.964784
# Minibatch accuracy: 62.5%
# Validation accuracy: 75.6%
# Minibatch loss at step 250: 0.687372
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.1%
# Minibatch loss at step 300: 0.986548
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.9%
# Minibatch loss at step 350: 0.709778
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.0%
# Minibatch loss at step 400: 0.716666
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.0%
# Minibatch loss at step 450: 0.584447
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.6%
# Minibatch loss at step 500: 1.103906
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.9%
# Minibatch loss at step 550: 1.196223
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 600: 1.089722
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.3%
# Minibatch loss at step 650: 0.534207
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.7%
# Minibatch loss at step 700: 0.907011
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 750: 0.472138
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 800: 0.499124
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 850: 0.096762
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.1%
# Minibatch loss at step 900: 0.445887
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 950: 1.229156
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.3%
# Minibatch loss at step 1000: 0.300185
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.0%
# Test accuracy: 90.7%

# %% [markdown]
# ## Problem 2
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic LeNet5 architecture, adding Dropout, and/or adding learning rate decay.

# %% [markdown]
#  LeNet5 architecture
#
# INPUT => CONV => RELU => POOL => CONV => RELU => POOL => FC => RELU => FC

# %% [markdown]
# ### A
# RELU ver of LeNet5

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

  def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1], padding='SAME')
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden1 = tf.nn.relu(conv + layer1_biases)
    hidden2 = maxpool2d(hidden1, k=2)
    conv = tf.nn.conv2d(hidden2, layer2_weights, [1, 1, 1, 1], padding='SAME')
    conv = maxpool2d(conv, k=2)
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.158324
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.227154
# Minibatch accuracy: 12.5%
# Validation accuracy: 18.6%
# Minibatch loss at step 100: 2.323533
# Minibatch accuracy: 18.8%
# Validation accuracy: 43.2%
# Minibatch loss at step 150: 0.707198
# Minibatch accuracy: 81.2%
# Validation accuracy: 64.4%
# Minibatch loss at step 200: 1.150596
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.2%
# Minibatch loss at step 250: 0.737464
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.9%
# Minibatch loss at step 300: 1.067357
# Minibatch accuracy: 56.2%
# Validation accuracy: 78.2%
# Minibatch loss at step 350: 0.848275
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.1%
# Minibatch loss at step 400: 0.757396
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.9%
# Minibatch loss at step 450: 0.604380
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.0%
# Minibatch loss at step 500: 1.245104
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.8%
# Minibatch loss at step 550: 1.152044
# Minibatch accuracy: 56.2%
# Validation accuracy: 81.6%
# Minibatch loss at step 600: 0.904122
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.2%
# Minibatch loss at step 650: 0.640925
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 700: 0.961045
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.4%
# Minibatch loss at step 750: 0.445955
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 800: 0.562030
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.3%
# Minibatch loss at step 850: 0.149959
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.2%
# Minibatch loss at step 900: 0.485973
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.9%
# Minibatch loss at step 950: 0.992953
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.7%
# Minibatch loss at step 1000: 0.270290
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.4%
# Test accuracy: 90.5%

# %% [markdown]
#  ### B
#  tanh ver of LeNet5

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

  def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1], padding='SAME')
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden1 = tf.nn.tanh(conv + layer1_biases)
    hidden2 = maxpool2d(hidden1, k=2)
    conv = tf.nn.conv2d(hidden2, layer2_weights, [1, 1, 1, 1], padding='SAME')
    conv = maxpool2d(conv, k=2)
    hidden = tf.nn.tanh(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.193843
# Minibatch accuracy: 6.2%
# Validation accuracy: 4.0%
# Minibatch loss at step 50: 1.961899
# Minibatch accuracy: 31.2%
# Validation accuracy: 43.4%
# Minibatch loss at step 100: 1.189775
# Minibatch accuracy: 62.5%
# Validation accuracy: 65.5%
# Minibatch loss at step 150: 0.474215
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.1%
# Minibatch loss at step 200: 0.930839
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.6%
# Minibatch loss at step 250: 0.635156
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.2%
# Minibatch loss at step 300: 0.910274
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.9%
# Minibatch loss at step 350: 0.593587
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.2%
# Minibatch loss at step 400: 0.732215
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.4%
# Minibatch loss at step 450: 0.392555
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 500: 1.164953
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.6%
# Minibatch loss at step 550: 1.145251
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.9%
# Minibatch loss at step 600: 0.990785
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.2%
# Minibatch loss at step 650: 0.700305
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.3%
# Minibatch loss at step 700: 0.852666
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.6%
# Minibatch loss at step 750: 0.293173
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 800: 0.556009
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 850: 0.178893
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.3%
# Minibatch loss at step 900: 0.471064
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.4%
# Minibatch loss at step 950: 1.273037
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 1000: 0.195455
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.2%
# Test accuracy: 89.4%

# %% [markdown]
# ### C
# relu + dropout

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size//2, patch_size//2, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  keep_prob = tf.placeholder("float")

  def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1], padding='SAME')
  
  # Model.
  def model(data, keep_prob):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden1 = tf.nn.relu(conv + layer1_biases)
    
    hidden2 = tf.nn.dropout(hidden1, keep_prob)
    #hidden2 = maxpool2d(hidden1, k=2)
    conv = tf.nn.conv2d(hidden2, layer2_weights, [1, 1, 1, 1], padding='SAME')
    #conv = maxpool2d(conv, k=2)
    conv = tf.nn.dropout(hidden1, keep_prob)
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset, keep_prob)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~/anaconda3/envs/TensorFlow/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in _call_cpp_shape_fn_impl(op, input_tensors_needed, input_tensors_as_shapes_needed, require_shape_fn)
#     685           graph_def_version, node_def_str, input_shapes, input_tensors,
# --> 686           input_tensors_as_shapes, status)
#     687   except errors.InvalidArgumentError as err:
#
# ~/anaconda3/envs/TensorFlow/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
#     474     # Delete the underlying status object from memory otherwise it stays alive
#
# InvalidArgumentError: Dimensions must be equal, but are 12544 and 784 for 'MatMul' (op: 'MatMul') with input shapes: [16,12544], [784,64].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-1d77e7ef1fff> in <module>()
#      52
#      53   # Training computation.
# ---> 54   logits = model(tf_train_dataset, keep_prob)
#      55   loss = tf.reduce_mean(
#      56     tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
#
# <ipython-input-15-1d77e7ef1fff> in model(data, keep_prob)
#      48     shape = hidden.get_shape().as_list()
#      49     reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
# ---> 50     hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
#      51     return tf.matmul(hidden, layer4_weights) + layer4_biases
#      52
#
# ~/anaconda3/envs/TensorFlow/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in matmul(a, b, transpose_a, transpose_b, adjoint_a, adjoint_b, a_is_sparse, b_is_sparse, name)
#    1889     else:
#    1890       return gen_math_ops._mat_mul(
# -> 1891           a, b, transpose_a=transpose_a, transpose_b=transpose_b, name=name)
#    1892
#    1893
#
# ~/anaconda3/envs/TensorFlow/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py in _mat_mul(a, b, transpose_a, transpose_b, name)
#    2435     _, _, _op = _op_def_lib._apply_op_helper(
#    2436         "MatMul", a=a, b=b, transpose_a=transpose_a, transpose_b=transpose_b,
# -> 2437         name=name)
#    2438     _result = _op.outputs[:]
#    2439     _inputs_flat = _op.inputs
#
# ~/anaconda3/envs/TensorFlow/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     785         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     786                          input_types=input_types, attrs=attr_protos,
# --> 787                          op_def=op_def)
#     788       return output_structure, op_def.is_stateful, op
#     789
#
# ~/anaconda3/envs/TensorFlow/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    2956         op_def=op_def)
#    2957     if compute_shapes:
# -> 2958       set_shapes_for_outputs(ret)
#    2959     self._add_op(ret)
#    2960     self._record_op_seen_by_control_dependencies(ret)
#
# ~/anaconda3/envs/TensorFlow/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in set_shapes_for_outputs(op)
#    2207       shape_func = _call_cpp_shape_fn_and_require_op
#    2208
# -> 2209   shapes = shape_func(op)
#    2210   if shapes is None:
#    2211     raise RuntimeError(
#
# ~/anaconda3/envs/TensorFlow/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in call_with_requiring(op)
#    2157
#    2158   def call_with_requiring(op):
# -> 2159     return call_cpp_shape_fn(op, require_shape_fn=True)
#    2160
#    2161   _call_cpp_shape_fn_and_require_op = call_with_requiring
#
# ~/anaconda3/envs/TensorFlow/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in call_cpp_shape_fn(op, require_shape_fn)
#     625     res = _call_cpp_shape_fn_impl(op, input_tensors_needed,
#     626                                   input_tensors_as_shapes_needed,
# --> 627                                   require_shape_fn)
#     628     if not isinstance(res, dict):
#     629       # Handles the case where _call_cpp_shape_fn_impl calls unknown_shape(op).
#
# ~/anaconda3/envs/TensorFlow/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in _call_cpp_shape_fn_impl(op, input_tensors_needed, input_tensors_as_shapes_needed, require_shape_fn)
#     689       missing_shape_fn = True
#     690     else:
# --> 691       raise ValueError(err.message)
#     692
#     693   if missing_shape_fn:
#
# ValueError: Dimensions must be equal, but are 12544 and 784 for 'MatMul' (op: 'MatMul') with input shapes: [16,12544], [784,64].

# %%
num_steps = 1001
for kp in [0.5, 0.6, 0.7, 0.9, 0.9, 1.0]:
    with tf.Session(graph=graph) as session:
      tf.global_variables_initializer().run()
      print('Initialized')
      for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob : kp}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
          print('Minibatch loss at step %d: %f' % (step, l))
          print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
          print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))
      print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-51e9ed0b136c> in <module>()
#       8         batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
#       9         batch_labels = train_labels[offset:(offset + batch_size), :]
# ---> 10         feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob : kp}
#      11         _, l, predictions = session.run(
#      12           [optimizer, loss, train_prediction], feed_dict=feed_dict)
#
# NameError: name 'keep_prob' is not defined

# %% [markdown]
# ### D
# learning rate Varied

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

  def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1], padding='SAME')
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden1 = tf.nn.relu(conv + layer1_biases)
    hidden2 = maxpool2d(hidden1, k=2)
    conv = tf.nn.conv2d(hidden2, layer2_weights, [1, 1, 1, 1], padding='SAME')
    conv = maxpool2d(conv, k=2)
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  global_step = tf.Variable(0)  # count the number of steps taken.
  learnr = tf.placeholder("float")
  learning_rate = tf.train.exponential_decay(learnr, global_step, 100000, 0.95, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step= global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001
for lr in np.arange(0.001, 0.01, 0.001).tolist():
    with tf.Session(graph=graph) as session:
      tf.global_variables_initializer().run()
      print('Initialized learning rate = ', lr )
      for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, learnr : lr}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
          print('Minibatch loss at step %d: %f' % (step, l))
          print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
          print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))
      print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized learning rate =  0.001
# Minibatch loss at step 0: 2.738551
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.320392
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.2%
# Minibatch loss at step 100: 2.357557
# Minibatch accuracy: 0.0%
# Validation accuracy: 12.9%
# Minibatch loss at step 150: 2.342942
# Minibatch accuracy: 6.2%
# Validation accuracy: 14.7%
# Minibatch loss at step 200: 2.244581
# Minibatch accuracy: 6.2%
# Validation accuracy: 14.7%
# Minibatch loss at step 250: 2.262927
# Minibatch accuracy: 12.5%
# Validation accuracy: 15.0%
# Minibatch loss at step 300: 2.251117
# Minibatch accuracy: 12.5%
# Validation accuracy: 22.3%
# Minibatch loss at step 350: 2.117258
# Minibatch accuracy: 18.8%
# Validation accuracy: 21.4%
# Minibatch loss at step 400: 2.209620
# Minibatch accuracy: 18.8%
# Validation accuracy: 24.7%
# Minibatch loss at step 450: 2.174221
# Minibatch accuracy: 25.0%
# Validation accuracy: 28.9%
# Minibatch loss at step 500: 2.147236
# Minibatch accuracy: 31.2%
# Validation accuracy: 33.1%
# Minibatch loss at step 550: 2.112123
# Minibatch accuracy: 31.2%
# Validation accuracy: 33.7%
# Minibatch loss at step 600: 1.884679
# Minibatch accuracy: 50.0%
# Validation accuracy: 42.2%
# Minibatch loss at step 650: 2.023436
# Minibatch accuracy: 37.5%
# Validation accuracy: 50.4%
# Minibatch loss at step 700: 2.031424
# Minibatch accuracy: 25.0%
# Validation accuracy: 45.6%
# Minibatch loss at step 750: 1.865946
# Minibatch accuracy: 37.5%
# Validation accuracy: 48.1%
# Minibatch loss at step 800: 1.844493
# Minibatch accuracy: 50.0%
# Validation accuracy: 52.0%
# Minibatch loss at step 850: 1.600291
# Minibatch accuracy: 87.5%
# Validation accuracy: 57.1%
# Minibatch loss at step 900: 1.473992
# Minibatch accuracy: 75.0%
# Validation accuracy: 58.9%
# Minibatch loss at step 950: 1.542088
# Minibatch accuracy: 75.0%
# Validation accuracy: 60.2%
# Minibatch loss at step 1000: 1.364305
# Minibatch accuracy: 68.8%
# Validation accuracy: 58.9%
# Test accuracy: 63.3%
# Initialized learning rate =  0.002
# Minibatch loss at step 0: 3.438492
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.322834
# Minibatch accuracy: 6.2%
# Validation accuracy: 13.8%
# Minibatch loss at step 100: 2.242631
# Minibatch accuracy: 12.5%
# Validation accuracy: 21.1%
# Minibatch loss at step 150: 2.078774
# Minibatch accuracy: 31.2%
# Validation accuracy: 24.1%
# Minibatch loss at step 200: 2.135681
# Minibatch accuracy: 31.2%
# Validation accuracy: 31.8%
# Minibatch loss at step 250: 1.962785
# Minibatch accuracy: 37.5%
# Validation accuracy: 29.8%
# Minibatch loss at step 300: 1.900126
# Minibatch accuracy: 56.2%
# Validation accuracy: 43.8%
# Minibatch loss at step 350: 1.788384
# Minibatch accuracy: 56.2%
# Validation accuracy: 42.4%
# Minibatch loss at step 400: 1.844229
# Minibatch accuracy: 25.0%
# Validation accuracy: 44.4%
# Minibatch loss at step 450: 1.482308
# Minibatch accuracy: 68.8%
# Validation accuracy: 51.5%
# Minibatch loss at step 500: 1.580993
# Minibatch accuracy: 62.5%
# Validation accuracy: 55.8%
# Minibatch loss at step 550: 1.826478
# Minibatch accuracy: 31.2%
# Validation accuracy: 59.2%
# Minibatch loss at step 600: 1.408483
# Minibatch accuracy: 68.8%
# Validation accuracy: 61.0%
# Minibatch loss at step 650: 1.539151
# Minibatch accuracy: 56.2%
# Validation accuracy: 66.6%
# Minibatch loss at step 700: 1.276869
# Minibatch accuracy: 62.5%
# Validation accuracy: 63.4%
# Minibatch loss at step 750: 1.290335
# Minibatch accuracy: 62.5%
# Validation accuracy: 68.5%
# Minibatch loss at step 800: 1.184278
# Minibatch accuracy: 68.8%
# Validation accuracy: 71.2%
# Minibatch loss at step 850: 0.658779
# Minibatch accuracy: 81.2%
# Validation accuracy: 70.8%
# Minibatch loss at step 900: 0.845294
# Minibatch accuracy: 87.5%
# Validation accuracy: 71.8%
# Minibatch loss at step 950: 1.166155
# Minibatch accuracy: 68.8%
# Validation accuracy: 74.7%
# Minibatch loss at step 1000: 0.544374
# Minibatch accuracy: 93.8%
# Validation accuracy: 72.2%
# Test accuracy: 78.5%
# Initialized learning rate =  0.003
# Minibatch loss at step 0: 2.771860
# Minibatch accuracy: 12.5%
# Validation accuracy: 12.2%
# Minibatch loss at step 50: 2.173342
# Minibatch accuracy: 18.8%
# Validation accuracy: 11.9%
# Minibatch loss at step 100: 2.277573
# Minibatch accuracy: 6.2%
# Validation accuracy: 23.6%
# Minibatch loss at step 150: 2.075756
# Minibatch accuracy: 31.2%
# Validation accuracy: 24.7%
# Minibatch loss at step 200: 1.943760
# Minibatch accuracy: 37.5%
# Validation accuracy: 27.5%
# Minibatch loss at step 250: 2.026906
# Minibatch accuracy: 31.2%
# Validation accuracy: 26.0%
# Minibatch loss at step 300: 1.974185
# Minibatch accuracy: 31.2%
# Validation accuracy: 45.0%
# Minibatch loss at step 350: 1.710773
# Minibatch accuracy: 37.5%
# Validation accuracy: 42.3%
# Minibatch loss at step 400: 1.661749
# Minibatch accuracy: 37.5%
# Validation accuracy: 48.4%
# Minibatch loss at step 450: 1.302005
# Minibatch accuracy: 62.5%
# Validation accuracy: 52.7%
# Minibatch loss at step 500: 1.414111
# Minibatch accuracy: 62.5%
# Validation accuracy: 60.1%
# Minibatch loss at step 550: 1.858984
# Minibatch accuracy: 43.8%
# Validation accuracy: 61.0%
# Minibatch loss at step 600: 1.146350
# Minibatch accuracy: 68.8%
# Validation accuracy: 63.4%
# Minibatch loss at step 650: 1.422795
# Minibatch accuracy: 56.2%
# Validation accuracy: 69.8%
# Minibatch loss at step 700: 1.154688
# Minibatch accuracy: 56.2%
# Validation accuracy: 64.1%
# Minibatch loss at step 750: 0.937399
# Minibatch accuracy: 75.0%
# Validation accuracy: 71.5%
# Minibatch loss at step 800: 1.056527
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.7%
# Minibatch loss at step 850: 0.701404
# Minibatch accuracy: 81.2%
# Validation accuracy: 72.2%
# Minibatch loss at step 900: 0.953546
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.2%
# Minibatch loss at step 950: 1.089704
# Minibatch accuracy: 56.2%
# Validation accuracy: 75.0%
# Minibatch loss at step 1000: 0.550019
# Minibatch accuracy: 93.8%
# Validation accuracy: 74.2%
# Test accuracy: 81.4%
# Initialized learning rate =  0.004
# Minibatch loss at step 0: 3.480037
# Minibatch accuracy: 6.2%
# Validation accuracy: 9.7%
# Minibatch loss at step 50: 2.314022
# Minibatch accuracy: 6.2%
# Validation accuracy: 12.7%
# Minibatch loss at step 100: 2.241084
# Minibatch accuracy: 18.8%
# Validation accuracy: 27.4%
# Minibatch loss at step 150: 1.982793
# Minibatch accuracy: 25.0%
# Validation accuracy: 31.4%
# Minibatch loss at step 200: 1.730250
# Minibatch accuracy: 43.8%
# Validation accuracy: 34.5%
# Minibatch loss at step 250: 1.628564
# Minibatch accuracy: 50.0%
# Validation accuracy: 43.0%
# Minibatch loss at step 300: 1.418786
# Minibatch accuracy: 62.5%
# Validation accuracy: 55.2%
# Minibatch loss at step 350: 1.289102
# Minibatch accuracy: 68.8%
# Validation accuracy: 59.2%
# Minibatch loss at step 400: 1.084847
# Minibatch accuracy: 62.5%
# Validation accuracy: 59.3%
# Minibatch loss at step 450: 0.880492
# Minibatch accuracy: 81.2%
# Validation accuracy: 67.1%
# Minibatch loss at step 500: 1.230677
# Minibatch accuracy: 75.0%
# Validation accuracy: 70.8%
# Minibatch loss at step 550: 1.576706
# Minibatch accuracy: 56.2%
# Validation accuracy: 72.4%
# Minibatch loss at step 600: 1.150610
# Minibatch accuracy: 68.8%
# Validation accuracy: 73.7%
# Minibatch loss at step 650: 1.005759
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.8%
# Minibatch loss at step 700: 1.040350
# Minibatch accuracy: 68.8%
# Validation accuracy: 73.4%
# Minibatch loss at step 750: 0.511621
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.8%
# Minibatch loss at step 800: 0.875528
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.5%
# Minibatch loss at step 850: 0.410219
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.1%
# Minibatch loss at step 900: 0.669999
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.4%
# Minibatch loss at step 950: 1.185979
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.7%
# Minibatch loss at step 1000: 0.273415
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.0%
# Test accuracy: 85.3%
# Initialized learning rate =  0.005
# Minibatch loss at step 0: 2.924938
# Minibatch accuracy: 6.2%
# Validation accuracy: 13.4%
# Minibatch loss at step 50: 2.305771
# Minibatch accuracy: 12.5%
# Validation accuracy: 18.1%
# Minibatch loss at step 100: 2.018710
# Minibatch accuracy: 37.5%
# Validation accuracy: 32.4%
# Minibatch loss at step 150: 1.798923
# Minibatch accuracy: 25.0%
# Validation accuracy: 35.7%
# Minibatch loss at step 200: 1.653010
# Minibatch accuracy: 56.2%
# Validation accuracy: 49.6%
# Minibatch loss at step 250: 1.286072
# Minibatch accuracy: 62.5%
# Validation accuracy: 57.5%
# Minibatch loss at step 300: 1.286100
# Minibatch accuracy: 68.8%
# Validation accuracy: 70.2%
# Minibatch loss at step 350: 1.027171
# Minibatch accuracy: 75.0%
# Validation accuracy: 67.8%
# Minibatch loss at step 400: 0.886006
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.9%
# Minibatch loss at step 450: 0.804018
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.6%
# Minibatch loss at step 500: 1.130958
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.5%
# Minibatch loss at step 550: 1.419582
# Minibatch accuracy: 62.5%
# Validation accuracy: 75.8%
# Minibatch loss at step 600: 1.024898
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.0%
# Minibatch loss at step 650: 0.963385
# Minibatch accuracy: 56.2%
# Validation accuracy: 77.1%
# Minibatch loss at step 700: 1.037287
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.0%
# Minibatch loss at step 750: 0.622661
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.1%
# Minibatch loss at step 800: 0.855257
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 850: 0.259276
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.8%
# Minibatch loss at step 900: 0.674393
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.2%
# Minibatch loss at step 950: 1.144841
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.3%
# Minibatch loss at step 1000: 0.377815
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.0%
# Test accuracy: 86.4%
# Initialized learning rate =  0.006
# Minibatch loss at step 0: 3.193133
# Minibatch accuracy: 6.2%
# Validation accuracy: 9.2%
# Minibatch loss at step 50: 2.315058
# Minibatch accuracy: 6.2%
# Validation accuracy: 17.8%
# Minibatch loss at step 100: 2.111774
# Minibatch accuracy: 25.0%
# Validation accuracy: 32.6%
# Minibatch loss at step 150: 1.815311
# Minibatch accuracy: 37.5%
# Validation accuracy: 33.0%
# Minibatch loss at step 200: 1.500912
# Minibatch accuracy: 56.2%
# Validation accuracy: 44.6%
# Minibatch loss at step 250: 1.189256
# Minibatch accuracy: 56.2%
# Validation accuracy: 53.2%
# Minibatch loss at step 300: 1.312989
# Minibatch accuracy: 68.8%
# Validation accuracy: 67.8%
# Minibatch loss at step 350: 1.126224
# Minibatch accuracy: 62.5%
# Validation accuracy: 69.9%
# Minibatch loss at step 400: 0.833777
# Minibatch accuracy: 87.5%
# Validation accuracy: 70.8%
# Minibatch loss at step 450: 0.753409
# Minibatch accuracy: 93.8%
# Validation accuracy: 72.9%
# Minibatch loss at step 500: 1.403635
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.5%
# Minibatch loss at step 550: 1.272251
# Minibatch accuracy: 62.5%
# Validation accuracy: 76.0%
# Minibatch loss at step 600: 1.165450
# Minibatch accuracy: 62.5%
# Validation accuracy: 75.5%
# Minibatch loss at step 650: 0.894161
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 700: 0.960938
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.6%
# Minibatch loss at step 750: 0.533216
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.2%
# Minibatch loss at step 800: 0.970333
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.9%
# Minibatch loss at step 850: 0.228475
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.7%
# Minibatch loss at step 900: 0.526839
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.9%
# Minibatch loss at step 950: 1.154221
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.8%
# Minibatch loss at step 1000: 0.283509
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.8%
# Test accuracy: 86.1%
# Initialized learning rate =  0.007
# Minibatch loss at step 0: 5.107148
# Minibatch accuracy: 12.5%
# Validation accuracy: 7.9%
# Minibatch loss at step 50: 2.139305
# Minibatch accuracy: 18.8%
# Validation accuracy: 23.8%
# Minibatch loss at step 100: 1.943672
# Minibatch accuracy: 50.0%
# Validation accuracy: 39.8%
# Minibatch loss at step 150: 1.480891
# Minibatch accuracy: 37.5%
# Validation accuracy: 45.2%
# Minibatch loss at step 200: 1.439624
# Minibatch accuracy: 50.0%
# Validation accuracy: 60.1%
# Minibatch loss at step 250: 1.185381
# Minibatch accuracy: 56.2%
# Validation accuracy: 65.5%
# Minibatch loss at step 300: 1.132205
# Minibatch accuracy: 75.0%
# Validation accuracy: 72.4%
# Minibatch loss at step 350: 0.790078
# Minibatch accuracy: 81.2%
# Validation accuracy: 70.3%
# Minibatch loss at step 400: 0.944122
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.7%
# Minibatch loss at step 450: 0.688397
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.1%
# Minibatch loss at step 500: 1.445440
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.7%
# Minibatch loss at step 550: 1.468138
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.3%
# Minibatch loss at step 600: 1.154302
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.3%
# Minibatch loss at step 650: 0.932537
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.5%
# Minibatch loss at step 700: 0.921470
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.7%
# Minibatch loss at step 750: 0.564374
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.0%
# Minibatch loss at step 800: 0.859712
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 850: 0.209691
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.3%
# Minibatch loss at step 900: 0.679716
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 950: 1.177576
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 1000: 0.263376
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Test accuracy: 87.2%
# Initialized learning rate =  0.008
# Minibatch loss at step 0: 3.475616
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.1%
# Minibatch loss at step 50: 2.187274
# Minibatch accuracy: 12.5%
# Validation accuracy: 23.6%
# Minibatch loss at step 100: 1.921887
# Minibatch accuracy: 43.8%
# Validation accuracy: 44.5%
# Minibatch loss at step 150: 1.166083
# Minibatch accuracy: 56.2%
# Validation accuracy: 53.8%
# Minibatch loss at step 200: 1.332022
# Minibatch accuracy: 56.2%
# Validation accuracy: 65.4%
# Minibatch loss at step 250: 1.035085
# Minibatch accuracy: 62.5%
# Validation accuracy: 71.5%
# Minibatch loss at step 300: 1.052740
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.6%
# Minibatch loss at step 350: 0.731379
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.2%
# Minibatch loss at step 400: 0.799656
# Minibatch accuracy: 62.5%
# Validation accuracy: 75.1%
# Minibatch loss at step 450: 0.644455
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.9%
# Minibatch loss at step 500: 1.395810
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.0%
# Minibatch loss at step 550: 1.447901
# Minibatch accuracy: 50.0%
# Validation accuracy: 77.4%
# Minibatch loss at step 600: 1.028272
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 650: 0.940309
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.7%
# Minibatch loss at step 700: 1.042653
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.6%
# Minibatch loss at step 750: 0.440001
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 800: 0.732528
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.1%
# Minibatch loss at step 850: 0.212097
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 900: 0.691844
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 950: 1.136682
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.5%
# Minibatch loss at step 1000: 0.371656
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Test accuracy: 87.6%
# Initialized learning rate =  0.009000000000000001
# Minibatch loss at step 0: 3.464483
# Minibatch accuracy: 12.5%
# Validation accuracy: 11.0%
# Minibatch loss at step 50: 2.168966
# Minibatch accuracy: 25.0%
# Validation accuracy: 32.0%
# Minibatch loss at step 100: 1.690698
# Minibatch accuracy: 43.8%
# Validation accuracy: 51.5%
# Minibatch loss at step 150: 1.036596
# Minibatch accuracy: 68.8%
# Validation accuracy: 59.3%
# Minibatch loss at step 200: 1.213302
# Minibatch accuracy: 62.5%
# Validation accuracy: 69.2%
# Minibatch loss at step 250: 0.915357
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.2%
# Minibatch loss at step 300: 1.017440
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.9%
# Minibatch loss at step 350: 0.740199
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.5%
# Minibatch loss at step 400: 0.845363
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.8%
# Minibatch loss at step 450: 0.723468
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.3%
# Minibatch loss at step 500: 1.412836
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.9%
# Minibatch loss at step 550: 1.109938
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.7%
# Minibatch loss at step 600: 1.053776
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.7%
# Minibatch loss at step 650: 1.005914
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 700: 0.905599
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 750: 0.566904
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 800: 0.837793
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.0%
# Minibatch loss at step 850: 0.162979
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 900: 0.459780
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.1%
# Minibatch loss at step 950: 1.216731
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.3%
# Minibatch loss at step 1000: 0.344582
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.4%
# Test accuracy: 88.4%

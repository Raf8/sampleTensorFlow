# %% [markdown]
# # Deep Learning
# ## Assignment 3
#
# Previously in 2_fullyconnected.ipynb, you trained a logistic regression and a neural network model.
#
# The goal of this assignment is to explore regularization techniques.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
# Out:
# /home/raf/anaconda3/envs/TensorFlow/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /home/raf/anaconda3/envs/TensorFlow/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# First reload the data we generated in notmist.ipynb.

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a shape that's more adapted to the models we're going to train:
#
# * data as a flat matrix,
# * labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10

def reformat(dataset, labels):
  dataset = dataset.reshape((-1, image_size * image_size)).astype(np.float32)
  # Map 2 to [0.0, 1.0, 0.0 ...], 3 to [0.0, 0.0, 1.0 ...]
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 784) (200000, 10)
# Validation set (10000, 784) (10000, 10)
# Test set (10000, 784) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# ### Problem 1
#
# Introduce and tune L2 regularization for both logistic and neural network models. Remember that L2 amounts to adding a penalty on the norm of the weights to the loss. In TensorFlow, you can compue the L2 loss for a tensor t using nn.l2_loss(t). The right amount of regularization should improve your validation / test accuracy.

# %% [markdown]
# ###  logistic regression with l2 loss function
#
# regularizing with beta = 0.01

# %%
# multinomial logistic regression 
train_subset = 10000
beta = 0.008

graph = tf.Graph()
with graph.as_default():

    # Input data.
    tf_train_dataset = tf.constant(train_dataset[:train_subset, :])
    tf_train_labels = tf.constant(train_labels[:train_subset])
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables    
    weights = tf.Variable(tf.truncated_normal([image_size * image_size, num_labels]))
    biases = tf.Variable(tf.zeros([num_labels]))
  
    # Training computation.
    logits = tf.nn.softmax(tf.matmul(tf_train_dataset, weights) + biases)
    
    # loss function using l2
    loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels) )
    loss = tf.reduce_mean(loss + beta * tf.nn.l2_loss(weights) )
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax( tf.matmul(tf_valid_dataset, weights) + biases )
    test_prediction = tf.nn.softmax(tf.matmul(tf_test_dataset, weights) + biases)

# %%
num_steps = 801

def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    for step in range(num_steps):
        
        _, l, predictions = session.run([optimizer, loss, train_prediction])

        if (step % 100 == 0):
            print('Loss at step %d: %f' % (step, l))
            print('Training accuracy: %.1f%%' % accuracy(
            predictions, train_labels[:train_subset, :]))
            print('Validation accuracy: %.1f%%' % accuracy( valid_prediction.eval(), valid_labels) )

    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Loss at step 0: 26.480192
# Training accuracy: 8.8%
# Validation accuracy: 9.5%
# Loss at step 100: 13.035336
# Training accuracy: 23.8%
# Validation accuracy: 23.9%
# Loss at step 200: 6.849258
# Training accuracy: 46.6%
# Validation accuracy: 47.0%
# Loss at step 300: 4.012233
# Training accuracy: 65.0%
# Validation accuracy: 64.9%
# Loss at step 400: 2.774629
# Training accuracy: 70.8%
# Validation accuracy: 70.6%
# Loss at step 500: 2.232380
# Training accuracy: 72.7%
# Validation accuracy: 72.2%
# Loss at step 600: 1.947636
# Training accuracy: 80.2%
# Validation accuracy: 79.5%
# Loss at step 700: 1.839847
# Training accuracy: 81.0%
# Validation accuracy: 80.3%
# Loss at step 800: 1.793015
# Training accuracy: 81.2%
# Validation accuracy: 80.6%
# Test accuracy: 87.6%

# %% [markdown]
# ### neural network with l2 loss function

# %%
batch_size = 128
beta = 0.01

graph = tf.Graph()
with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    weights = tf.Variable( tf.truncated_normal([image_size * image_size, num_labels]) )
    biases = tf.Variable(tf.zeros([num_labels]))
  
    # Training computation.
    logits = tf.matmul(tf_train_dataset, weights) + biases
    
    loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits = logits,labels = tf_train_labels) )
    loss = tf.reduce_mean( loss + beta * tf.nn.l2_loss(weights) )
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax( tf.matmul(tf_valid_dataset, weights) + biases)
    test_prediction = tf.nn.softmax(tf.matmul(tf_test_dataset, weights) + biases)

# %%
batch_size = 128
n_input = image_size * image_size
n_hidden_1 = 1024
n_classes = 10
beta = 0.005


graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, n_input))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, n_classes))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  weights = {
      'h1': tf.Variable(tf.random_normal([n_input, n_hidden_1])),
      'out': tf.Variable(tf.random_normal([n_hidden_1, n_classes]))
  }
  biases = {
      'b1': tf.Variable(tf.random_normal([n_hidden_1])),
      'out': tf.Variable(tf.random_normal([n_classes]))
  }

    
  # Training computation.
  layer_1 = tf.add(tf.matmul(tf_train_dataset, weights['h1']), biases['b1'])
  tf_layer = tf.nn.relu(layer_1)
  logits = tf.matmul(tf_layer, weights['out']) + biases['out']
  
  loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
  loss = tf.reduce_mean( loss + beta * tf.nn.l2_loss(weights['out']) )
  
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
    
  valid_relu = tf.nn.relu(tf.add(tf.matmul(tf_valid_dataset, weights['h1']), biases['b1']))
  valid_prediction = tf.nn.softmax(tf.add(tf.matmul(valid_relu, weights['out']), biases['out']))

  test_relu = tf.nn.relu(tf.add(tf.matmul(tf_test_dataset, weights['h1']), biases['b1']))
  test_prediction = tf.nn.softmax(tf.matmul(test_relu, weights['out']) +  biases['out'])

# %%
num_steps = 5001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print("Initialized")
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
            print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
    print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 521.647644
# Minibatch accuracy: 3.9%
# Validation accuracy: 25.7%
# Minibatch loss at step 500: 51.746742
# Minibatch accuracy: 64.8%
# Validation accuracy: 76.9%
# Minibatch loss at step 1000: 11.192792
# Minibatch accuracy: 78.1%
# Validation accuracy: 78.4%
# Minibatch loss at step 1500: 3.274352
# Minibatch accuracy: 89.1%
# Validation accuracy: 79.8%
# Minibatch loss at step 2000: 5.070520
# Minibatch accuracy: 80.5%
# Validation accuracy: 80.8%
# Minibatch loss at step 2500: 6.661446
# Minibatch accuracy: 78.1%
# Validation accuracy: 80.2%
# Minibatch loss at step 3000: 3.849973
# Minibatch accuracy: 80.5%
# Validation accuracy: 80.3%
# Minibatch loss at step 3500: 5.995305
# Minibatch accuracy: 76.6%
# Validation accuracy: 77.4%
# Minibatch loss at step 4000: 4.879106
# Minibatch accuracy: 80.5%
# Validation accuracy: 79.3%
# Minibatch loss at step 4500: 4.956207
# Minibatch accuracy: 82.0%
# Validation accuracy: 80.5%
# Minibatch loss at step 5000: 1.945428
# Minibatch accuracy: 85.9%
# Validation accuracy: 81.2%
# Test accuracy: 88.1%

# %% [markdown]
# ### Problem 2
#
# Let's demonstrate an extreme case of overfitting. Restrict your training data to just a few batches. What happens?

# %% [markdown]
# ### log reg with l2 loss and small training data

# %%
# multinomial logistic regression 
train_subset = 100
beta = 0.01

graph = tf.Graph()
with graph.as_default():

    # Input data.
    tf_train_dataset = tf.constant(train_dataset[:train_subset, :])
    tf_train_labels = tf.constant(train_labels[:train_subset])
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables    
    weights = tf.Variable(
    tf.truncated_normal([image_size * image_size, num_labels]))
    biases = tf.Variable(tf.zeros([num_labels]))
  
    # Training computation.
    logits = tf.matmul(tf_train_dataset, weights) + biases
    
    # loss function using l2
    loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits = logits, labels = tf_train_labels) )
    loss = tf.reduce_mean(loss + beta * tf.nn.l2_loss(weights) )
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax( tf.matmul(tf_valid_dataset, weights) + biases )
    test_prediction = tf.nn.softmax(tf.matmul(tf_test_dataset, weights) + biases)

# %%
num_steps = 801

def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])
init = tf.global_variables_initializer()
with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        
        _, l, predictions = session.run([optimizer, loss, train_prediction])

        if (step % 100 == 0):
            print('Loss at step %d: %f' % (step, l))
            print('Training accuracy: %.1f%%' % accuracy(
            predictions, train_labels[:train_subset, :]))
            print('Validation accuracy: %.1f%%' % accuracy( valid_prediction.eval(), valid_labels) )

    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Loss at step 0: 46.285088
# Training accuracy: 9.0%
# Validation accuracy: 14.2%
# Loss at step 100: 10.687040
# Training accuracy: 100.0%
# Validation accuracy: 49.0%
# Loss at step 200: 3.993535
# Training accuracy: 100.0%
# Validation accuracy: 56.1%
# Loss at step 300: 1.549081
# Training accuracy: 100.0%
# Validation accuracy: 62.5%
# Loss at step 400: 0.658004
# Training accuracy: 100.0%
# Validation accuracy: 65.6%
# Loss at step 500: 0.333275
# Training accuracy: 100.0%
# Validation accuracy: 66.5%
# Loss at step 600: 0.214715
# Training accuracy: 100.0%
# Validation accuracy: 66.9%
# Loss at step 700: 0.171290
# Training accuracy: 100.0%
# Validation accuracy: 66.9%
# Loss at step 800: 0.155299
# Training accuracy: 100.0%
# Validation accuracy: 67.0%
# Test accuracy: 74.0%

# %% [markdown]
# Training accuracy goes to 100% due to the small sample size, however, the model is not as good the validation samples.

# %% [markdown]
# ### neural network wiht l2 loss and small training data

# %%
batch_size = 128
n_input = image_size * image_size
n_hidden_1 = 1024
n_classes = 10
beta = 0.005


graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, n_input))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, n_classes))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  weights = {
      'h1': tf.Variable(tf.random_normal([n_input, n_hidden_1])),
      'out': tf.Variable(tf.random_normal([n_hidden_1, n_classes]))
  }
  biases = {
      'b1': tf.Variable(tf.random_normal([n_hidden_1])),
      'out': tf.Variable(tf.random_normal([n_classes]))
  }

    
  # Training computation.
  layer_1 = tf.add(tf.matmul(tf_train_dataset, weights['h1']), biases['b1'])
  tf_layer = tf.nn.relu(layer_1)
  logits = tf.matmul(tf_layer, weights['out']) + biases['out']
  
  loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
  loss = tf.reduce_mean( loss + beta * tf.nn.l2_loss(weights['out']) )
  
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
    
  valid_relu = tf.nn.relu(tf.add(tf.matmul(tf_valid_dataset, weights['h1']), biases['b1']))
  valid_prediction = tf.nn.softmax(tf.add(tf.matmul(valid_relu, weights['out']), biases['out']))

  test_relu = tf.nn.relu(tf.add(tf.matmul(tf_test_dataset, weights['h1']), biases['b1']))
  test_prediction = tf.nn.softmax(tf.matmul(test_relu, weights['out']) +  biases['out'])

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print("Initialized")
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
            print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
    print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 487.220001
# Minibatch accuracy: 9.4%
# Validation accuracy: 34.1%
# Minibatch loss at step 500: 29.892189
# Minibatch accuracy: 73.4%
# Validation accuracy: 79.2%
# Minibatch loss at step 1000: 8.690788
# Minibatch accuracy: 80.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 1500: 6.251252
# Minibatch accuracy: 84.4%
# Validation accuracy: 79.8%
# Minibatch loss at step 2000: 5.135604
# Minibatch accuracy: 82.0%
# Validation accuracy: 77.8%
# Minibatch loss at step 2500: 7.449934
# Minibatch accuracy: 77.3%
# Validation accuracy: 79.7%
# Minibatch loss at step 3000: 3.698263
# Minibatch accuracy: 82.8%
# Validation accuracy: 80.4%
# Test accuracy: 87.6%

# %%
num_steps = 3001

train_dataset_2 = train_dataset[:500, :]
train_labels_2 = train_labels[:500]

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print("Initialized")
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels_2.shape[0] - batch_size)
        
        batch_data = train_dataset_2[offset:(offset + batch_size), :]
        batch_labels = train_labels_2[offset:(offset + batch_size), :]
        
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
            print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
    print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 542.964111
# Minibatch accuracy: 7.0%
# Validation accuracy: 32.1%
# Minibatch loss at step 500: 2.294342
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.9%
# Minibatch loss at step 1000: 0.188208
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.1%
# Minibatch loss at step 1500: 0.017448
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.7%
# Minibatch loss at step 2000: 0.005176
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.8%
# Minibatch loss at step 2500: 0.004388
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.7%
# Minibatch loss at step 3000: 0.004237
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.6%
# Test accuracy: 84.1%

# %% [markdown]
# We see overfitting occuring on neural network model when the training set is 3 times smaller.

# %% [markdown]
# ## Problem 3
#
# Introduce Dropout on the hidden layer of the neural network. Remember: Dropout should only be introduced during training, not evaluation, otherwise your evaluation results would be stochastic as well. TensorFlow provides nn.dropout() for that, but you have to make sure it's only inserted during training.
#
# What happens to our extreme overfitting case?

# %%
batch_size = 128
beta = 0.001

graph = tf.Graph()
with graph.as_default():

    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # new hidden layer
    hidden_nodes = 1024
    hidden_weights = tf.Variable( tf.truncated_normal([image_size * image_size, hidden_nodes]) )
    hidden_biases = tf.Variable( tf.zeros([hidden_nodes]))
    hidden_layer = tf.nn.relu( tf.matmul( tf_train_dataset, hidden_weights) + hidden_biases)
    
    # add dropout on hidden layer
    keep_prob = tf.placeholder("float")
    hidden_layer_drop = tf.nn.dropout(hidden_layer, keep_prob)

    # Variables.
    weights = tf.Variable( tf.truncated_normal([hidden_nodes, num_labels])) 
    biases = tf.Variable(tf.zeros([num_labels]))

    # Training computation.
    logits = tf.matmul(hidden_layer_drop, weights) + biases
    loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels) )
    loss = tf.reduce_mean( loss + beta * tf.nn.l2_loss(weights) )

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_relu = tf.nn.relu(  tf.matmul(tf_valid_dataset, hidden_weights) + hidden_biases)
    valid_prediction = tf.nn.softmax( tf.matmul(valid_relu, weights) + biases) 

    test_relu = tf.nn.relu( tf.matmul( tf_test_dataset, hidden_weights) + hidden_biases)
    test_prediction = tf.nn.softmax(tf.matmul(test_relu, weights) + biases)

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print("Initialized")
    for step in range(num_steps):
        # Pick an offset within the training data, which has been randomized.
        # Note: we could use better randomization across epochs.
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        # Generate a minibatch.
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]

        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob : 0.5}
        _, l, predictions = session.run( [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
          print("Minibatch loss at step %d: %f" % (step, l))
          print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
          print("Validation accuracy: %.1f%%" % accuracy( valid_prediction.eval(), valid_labels) )
    print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 395.268829
# Minibatch accuracy: 14.8%
# Validation accuracy: 31.1%
# Minibatch loss at step 500: 16.951561
# Minibatch accuracy: 69.5%
# Validation accuracy: 79.9%
# Minibatch loss at step 1000: 17.043293
# Minibatch accuracy: 65.6%
# Validation accuracy: 78.7%
# Minibatch loss at step 1500: 7.137679
# Minibatch accuracy: 75.8%
# Validation accuracy: 79.3%
# Minibatch loss at step 2000: 11.012438
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.8%
# Minibatch loss at step 2500: 9.976499
# Minibatch accuracy: 70.3%
# Validation accuracy: 79.3%
# Minibatch loss at step 3000: 11.211316
# Minibatch accuracy: 75.8%
# Validation accuracy: 79.7%
# Test accuracy: 86.9%

# %%
num_steps = 3001

train_dataset_2 = train_dataset[:500, :]
train_labels_2 = train_labels[:500]

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print("Initialized")
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels_2.shape[0] - batch_size)
        
        batch_data = train_dataset_2[offset:(offset + batch_size), :]
        batch_labels = train_labels_2[offset:(offset + batch_size), :]
        
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob : 0.4}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
            print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
    print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 519.101990
# Minibatch accuracy: 9.4%
# Validation accuracy: 20.3%
# Minibatch loss at step 500: 4.203056
# Minibatch accuracy: 99.2%
# Validation accuracy: 77.9%
# Minibatch loss at step 1000: 2.073818
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.8%
# Minibatch loss at step 1500: 1.335716
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.9%
# Minibatch loss at step 2000: 0.885346
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.0%
# Minibatch loss at step 2500: 0.640769
# Minibatch accuracy: 99.2%
# Validation accuracy: 78.3%
# Minibatch loss at step 3000: 0.450377
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.0%
# Test accuracy: 85.3%

# %% [markdown]
# ### Problem 4
#
# Try to get the best performance you can using a multi-layer model! The best reported test accuracy using a deep network is 97.1%.
#
# One avenue you can explore is to add multiple layers.
#
# Another one is to use learning rate decay:
#
#     global_step = tf.Variable(0)  # count the number of steps taken.
#     learning_rate = tf.train.exponential_decay(0.5, step, ...)
#     optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

# %% [markdown]
# ### trying smaller beta and bigger num steps

# %%
batch_size = 128
beta = 0.0001

graph = tf.Graph()
with graph.as_default():

    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # new hidden layer
    hidden_nodes = 1024
    hidden_weights = tf.Variable( tf.truncated_normal([image_size * image_size, hidden_nodes]) )
    hidden_biases = tf.Variable( tf.zeros([hidden_nodes]))
    hidden_layer = tf.nn.relu( tf.matmul( tf_train_dataset, hidden_weights) + hidden_biases)
    
    # add dropout on hidden layer
    keep_prob = tf.placeholder("float")
    hidden_layer_drop = tf.nn.dropout(hidden_layer, keep_prob)

    # Variables.
    weights = tf.Variable( tf.truncated_normal([hidden_nodes, num_labels])) 
    biases = tf.Variable(tf.zeros([num_labels]))

    # Training computation.
    logits = tf.matmul(hidden_layer_drop, weights) + biases
    loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits=logits,labels=tf_train_labels) )
    loss = tf.reduce_mean( loss + beta * tf.nn.l2_loss(weights) )

    # Optimizer.
    global_step = tf.Variable(0, trainable=False)  # count the number of steps taken.
    starter_learning_rate = 0.5
    learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step,100000, 0.96, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_relu = tf.nn.relu(  tf.matmul(tf_valid_dataset, hidden_weights) + hidden_biases)
    valid_prediction = tf.nn.softmax( tf.matmul(valid_relu, weights) + biases) 

    test_relu = tf.nn.relu( tf.matmul( tf_test_dataset, hidden_weights) + hidden_biases)
    test_prediction = tf.nn.softmax(tf.matmul(test_relu, weights) + biases)

# %%
num_steps = 6001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print("Initialized")
    for step in range(num_steps):
        # Pick an offset within the training data, which has been randomized.
        # Note: we could use better randomization across epochs.
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        # Generate a minibatch.
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]

        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob : 0.5}
        _, l, predictions = session.run( [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
          print("Minibatch loss at step %d: %f" % (step, l))
          print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
          print("Validation accuracy: %.1f%%" % accuracy( valid_prediction.eval(), valid_labels) )
    print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 450.186035
# Minibatch accuracy: 12.5%
# Validation accuracy: 27.9%
# Minibatch loss at step 500: 18.637424
# Minibatch accuracy: 73.4%
# Validation accuracy: 79.1%
# Minibatch loss at step 1000: 14.024601
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.7%
# Minibatch loss at step 1500: 7.348411
# Minibatch accuracy: 78.1%
# Validation accuracy: 78.1%
# Minibatch loss at step 2000: 10.609426
# Minibatch accuracy: 70.3%
# Validation accuracy: 80.0%
# Minibatch loss at step 2500: 10.423684
# Minibatch accuracy: 67.2%
# Validation accuracy: 79.7%
# Minibatch loss at step 3000: 3.972826
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.5%
# Minibatch loss at step 3500: 13.815743
# Minibatch accuracy: 63.3%
# Validation accuracy: 80.4%
# Minibatch loss at step 4000: 6.062233
# Minibatch accuracy: 76.6%
# Validation accuracy: 80.0%
# Minibatch loss at step 4500: 5.052235
# Minibatch accuracy: 76.6%
# Validation accuracy: 79.7%
# Minibatch loss at step 5000: 0.900898
# Minibatch accuracy: 83.6%
# Validation accuracy: 80.9%
# Minibatch loss at step 5500: 5.415053
# Minibatch accuracy: 71.1%
# Validation accuracy: 80.5%
# Minibatch loss at step 6000: 2.641201
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.0%
# Test accuracy: 87.6%

# %% [markdown]
# ### trying keep prob of 0.1

# %%
batch_size = 128
beta = 0.0001

graph = tf.Graph()
with graph.as_default():

    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # new hidden layer
    hidden_nodes = 1024
    hidden_weights = tf.Variable( tf.truncated_normal([image_size * image_size, hidden_nodes]) )
    hidden_biases = tf.Variable( tf.zeros([hidden_nodes]))
    hidden_layer = tf.nn.relu( tf.matmul( tf_train_dataset, hidden_weights) + hidden_biases)
    
    # add dropout on hidden layer
    keep_prob = tf.placeholder("float")
    hidden_layer_drop = tf.nn.dropout(hidden_layer, keep_prob)

    # Variables.
    weights = tf.Variable( tf.truncated_normal([hidden_nodes, num_labels])) 
    biases = tf.Variable(tf.zeros([num_labels]))

    # Training computation.
    logits = tf.matmul(hidden_layer_drop, weights) + biases
    loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits=logits,labels=tf_train_labels) )
    loss = tf.reduce_mean( loss + beta * tf.nn.l2_loss(weights) )

    # Optimizer.
    global_step = tf.Variable(0, trainable=False)  # count the number of steps taken.
    starter_learning_rate = 0.5
    learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step,100000, 0.96, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_relu = tf.nn.relu(  tf.matmul(tf_valid_dataset, hidden_weights) + hidden_biases)
    valid_prediction = tf.nn.softmax( tf.matmul(valid_relu, weights) + biases) 

    test_relu = tf.nn.relu( tf.matmul( tf_test_dataset, hidden_weights) + hidden_biases)
    test_prediction = tf.nn.softmax(tf.matmul(test_relu, weights) + biases)

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print("Initialized")
    for step in range(num_steps):
        # Pick an offset within the training data, which has been randomized.
        # Note: we could use better randomization across epochs.
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        # Generate a minibatch.
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]

        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob : 0.1}
        _, l, predictions = session.run( [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
          print("Minibatch loss at step %d: %f" % (step, l))
          print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
          print("Validation accuracy: %.1f%%" % accuracy( valid_prediction.eval(), valid_labels) )
    print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 1105.149170
# Minibatch accuracy: 11.7%
# Validation accuracy: 25.5%
# Minibatch loss at step 500: 163221.000000
# Minibatch accuracy: 49.2%
# Validation accuracy: 73.0%
# Minibatch loss at step 1000: 9635577.000000
# Minibatch accuracy: 41.4%
# Validation accuracy: 63.4%
# Minibatch loss at step 1500: 504115456.000000
# Minibatch accuracy: 44.5%
# Validation accuracy: 70.1%
# Minibatch loss at step 2000: 26336778240.000000
# Minibatch accuracy: 43.0%
# Validation accuracy: 67.9%
# Minibatch loss at step 2500: 1150298619904.000000
# Minibatch accuracy: 50.0%
# Validation accuracy: 71.2%
# Minibatch loss at step 3000: 38355446267904.000000
# Minibatch accuracy: 46.9%
# Validation accuracy: 69.9%
# Test accuracy: 76.1%

# %% [markdown]
# ### trying with learning rate and multiple keep probs

# %%
batch_size = 128
beta = 0.001

graph = tf.Graph()
with graph.as_default():

    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # new hidden layer
    hidden_nodes = 1024
    hidden_weights = tf.Variable( tf.truncated_normal([image_size * image_size, hidden_nodes]) )
    hidden_biases = tf.Variable( tf.zeros([hidden_nodes]))
    hidden_layer = tf.nn.relu( tf.matmul( tf_train_dataset, hidden_weights) + hidden_biases)
    
    # add dropout on hidden layer
    keep_prob = tf.placeholder("float")
    hidden_layer_drop = tf.nn.dropout(hidden_layer, keep_prob)

    # Variables.
    weights = tf.Variable( tf.truncated_normal([hidden_nodes, num_labels])) 
    biases = tf.Variable(tf.zeros([num_labels]))

    # Training computation.
    logits = tf.matmul(hidden_layer_drop, weights) + biases
    loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels) )
    loss = tf.reduce_mean( loss + beta * tf.nn.l2_loss(weights) )

    # Optimizer.
    global_step = tf.Variable(0)  # count the number of steps taken.
    learning_rate = tf.train.exponential_decay(0.5, global_step, 100000, 0.95, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss, global_step=global_step)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_relu = tf.nn.relu(  tf.matmul(tf_valid_dataset, hidden_weights) + hidden_biases)
    valid_prediction = tf.nn.softmax( tf.matmul(valid_relu, weights) + biases) 

    test_relu = tf.nn.relu( tf.matmul( tf_test_dataset, hidden_weights) + hidden_biases)
    test_prediction = tf.nn.softmax(tf.matmul(test_relu, weights) + biases)

# %%
num_steps = 3001

for kp in [0.5, 0.6, 0.7, 0.9, 0.9, 1.0]:
    print( ">>with keep prob of "+ str(kp))
    with tf.Session(graph=graph) as session:
        tf.initialize_all_variables().run()
        print("Initialized")
        for step in range(num_steps):
            # Pick an offset within the training data, which has been randomized.
            # Note: we could use better randomization across epochs.
            offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
            # Generate a minibatch.
            batch_data = train_dataset[offset:(offset + batch_size), :]
            batch_labels = train_labels[offset:(offset + batch_size), :]

            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob : kp}
            _, l, predictions = session.run( [optimizer, loss, train_prediction], feed_dict=feed_dict)
            if (step % 500 == 0):
              print("Minibatch loss at step %d: %f" % (step, l))
              print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
              print("Validation accuracy: %.1f%%" % accuracy( valid_prediction.eval(), valid_labels) )
        print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# >>with keep prob of 0.5
# Initialized
# Minibatch loss at step 0: 464.414581
# Minibatch accuracy: 10.2%
# Validation accuracy: 39.0%
# Minibatch loss at step 500: 29.257612
# Minibatch accuracy: 65.6%
# Validation accuracy: 79.2%
# Minibatch loss at step 1000: 14.665298
# Minibatch accuracy: 73.4%
# Validation accuracy: 78.8%
# Minibatch loss at step 1500: 8.486413
# Minibatch accuracy: 78.9%
# Validation accuracy: 78.7%
# Minibatch loss at step 2000: 9.903625
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.1%
# Minibatch loss at step 2500: 8.026438
# Minibatch accuracy: 71.1%
# Validation accuracy: 78.6%
# Minibatch loss at step 3000: 5.399191
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.7%
# Test accuracy: 86.8%
# >>with keep prob of 0.6
# Initialized
# Minibatch loss at step 0: 551.104553
# Minibatch accuracy: 3.1%
# Validation accuracy: 31.9%
# Minibatch loss at step 500: 25.116768
# Minibatch accuracy: 76.6%
# Validation accuracy: 79.8%
# Minibatch loss at step 1000: 10.915282
# Minibatch accuracy: 74.2%
# Validation accuracy: 80.4%
# Minibatch loss at step 1500: 5.482883
# Minibatch accuracy: 76.6%
# Validation accuracy: 80.0%
# Minibatch loss at step 2000: 5.441989
# Minibatch accuracy: 79.7%
# Validation accuracy: 80.0%
# Minibatch loss at step 2500: 7.350424
# Minibatch accuracy: 74.2%
# Validation accuracy: 79.2%
# Minibatch loss at step 3000: 4.401402
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.7%
# Test accuracy: 87.0%
# >>with keep prob of 0.7
# Initialized
# Minibatch loss at step 0: 443.418915
# Minibatch accuracy: 10.2%
# Validation accuracy: 30.1%
# Minibatch loss at step 500: 32.322693
# Minibatch accuracy: 74.2%
# Validation accuracy: 80.3%
# Minibatch loss at step 1000: 8.830439
# Minibatch accuracy: 77.3%
# Validation accuracy: 79.5%
# Minibatch loss at step 1500: 3.354010
# Minibatch accuracy: 84.4%
# Validation accuracy: 78.0%
# Minibatch loss at step 2000: 4.877381
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.3%
# Minibatch loss at step 2500: 7.506157
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.5%
# Minibatch loss at step 3000: 4.018678
# Minibatch accuracy: 78.9%
# Validation accuracy: 80.4%
# Test accuracy: 87.4%
# >>with keep prob of 0.9
# Initialized
# Minibatch loss at step 0: 319.478882
# Minibatch accuracy: 9.4%
# Validation accuracy: 22.9%
# Minibatch loss at step 500: 14.252077
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.9%
# Minibatch loss at step 1000: 7.716067
# Minibatch accuracy: 76.6%
# Validation accuracy: 79.2%
# Minibatch loss at step 1500: 6.851719
# Minibatch accuracy: 89.1%
# Validation accuracy: 80.6%
# Minibatch loss at step 2000: 7.542279
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.7%
# Minibatch loss at step 2500: 5.461998
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.6%
# Minibatch loss at step 3000: 4.503949
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.4%
# Test accuracy: 87.8%
# >>with keep prob of 0.9
# Initialized
# Minibatch loss at step 0: 355.592010
# Minibatch accuracy: 10.2%
# Validation accuracy: 26.2%
# Minibatch loss at step 500: 16.915253
# Minibatch accuracy: 77.3%
# Validation accuracy: 80.1%
# Minibatch loss at step 1000: 9.280440
# Minibatch accuracy: 76.6%
# Validation accuracy: 80.4%
# Minibatch loss at step 1500: 5.410965
# Minibatch accuracy: 85.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 2000: 4.926195
# Minibatch accuracy: 76.6%
# Validation accuracy: 80.7%
# Minibatch loss at step 2500: 6.585638
# Minibatch accuracy: 77.3%
# Validation accuracy: 81.0%
# Minibatch loss at step 3000: 3.170352
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.7%
# Test accuracy: 89.0%
# >>with keep prob of 1.0
# Initialized
# Minibatch loss at step 0: 418.321777
# Minibatch accuracy: 8.6%
# Validation accuracy: 28.6%
# Minibatch loss at step 500: 17.644951
# Minibatch accuracy: 78.1%
# Validation accuracy: 79.8%
# Minibatch loss at step 1000: 8.303975
# Minibatch accuracy: 79.7%
# Validation accuracy: 80.6%
# Minibatch loss at step 1500: 3.502846
# Minibatch accuracy: 85.9%
# Validation accuracy: 80.0%
# Minibatch loss at step 2000: 7.764772
# Minibatch accuracy: 78.9%
# Validation accuracy: 79.9%
# Minibatch loss at step 2500: 6.613994
# Minibatch accuracy: 76.6%
# Validation accuracy: 82.0%
# Minibatch loss at step 3000: 3.457388
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.0%
# Test accuracy: 87.5%

# %% [markdown]
# ### trying different learning rates

# %%
batch_size = 128
beta = 0.001

graph = tf.Graph()
with graph.as_default():

    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # new hidden layer
    hidden_nodes = 1024
    hidden_weights = tf.Variable( tf.truncated_normal([image_size * image_size, hidden_nodes]) )
    hidden_biases = tf.Variable( tf.zeros([hidden_nodes]))
    hidden_layer = tf.nn.relu( tf.matmul( tf_train_dataset, hidden_weights) + hidden_biases)
    
    # add dropout on hidden layer
    keep_prob = tf.placeholder("float")
    hidden_layer_drop = tf.nn.dropout(hidden_layer, keep_prob)

    # Variables.
    weights = tf.Variable( tf.truncated_normal([hidden_nodes, num_labels])) 
    biases = tf.Variable(tf.zeros([num_labels]))

    # Training computation.
    logits = tf.matmul(hidden_layer_drop, weights) + biases
    loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels) )
    loss = tf.reduce_mean( loss + beta * tf.nn.l2_loss(weights) )

    # Optimizer.
    global_step = tf.Variable(0)  # count the number of steps taken.
    learnr = tf.placeholder("float")
    learning_rate = tf.train.exponential_decay(learnr, global_step, 100000, 0.95, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss, global_step=global_step)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_relu = tf.nn.relu(  tf.matmul(tf_valid_dataset, hidden_weights) + hidden_biases)
    valid_prediction = tf.nn.softmax( tf.matmul(valid_relu, weights) + biases) 

    test_relu = tf.nn.relu( tf.matmul( tf_test_dataset, hidden_weights) + hidden_biases)
    test_prediction = tf.nn.softmax(tf.matmul(test_relu, weights) + biases)

# %%
for lr in np.arange(0.0001, 0.001, 0.0001).tolist():

    print('>> trying learning rate of ' + str(lr))
    with tf.Session(graph=graph) as session:
        tf.global_variables_initializer().run()
        print("Initialized")
        for step in range(num_steps):
            # Pick an offset within the training data, which has been randomized.
            # Note: we could use better randomization across epochs.
            offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
            # Generate a minibatch.
            batch_data = train_dataset[offset:(offset + batch_size), :]
            batch_labels = train_labels[offset:(offset + batch_size), :]

            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob : 1.0, learnr : lr}
            _, l, predictions = session.run( [optimizer, loss, train_prediction], feed_dict=feed_dict)
            if (step % 500 == 0):
              print("Minibatch loss at step %d: %f" % (step, l))
              print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
              print("Validation accuracy: %.1f%%" % accuracy( valid_prediction.eval(), valid_labels) )
        print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# >> trying learning rate of 0.0001
# Initialized
# Minibatch loss at step 0: 379.620422
# Minibatch accuracy: 10.9%
# Validation accuracy: 35.7%
# Minibatch loss at step 500: 10.390085
# Minibatch accuracy: 78.9%
# Validation accuracy: 80.6%
# Minibatch loss at step 1000: 9.908013
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.7%
# Minibatch loss at step 1500: 3.756989
# Minibatch accuracy: 85.9%
# Validation accuracy: 80.2%
# Minibatch loss at step 2000: 4.072092
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.4%
# Minibatch loss at step 2500: 6.320272
# Minibatch accuracy: 76.6%
# Validation accuracy: 81.0%
# Minibatch loss at step 3000: 3.303612
# Minibatch accuracy: 85.2%
# Validation accuracy: 80.8%
# Test accuracy: 87.6%
# >> trying learning rate of 0.0002
# Initialized
# Minibatch loss at step 0: 366.295380
# Minibatch accuracy: 11.7%
# Validation accuracy: 22.0%
# Minibatch loss at step 500: 7.961016
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.3%
# Minibatch loss at step 1000: 9.721804
# Minibatch accuracy: 77.3%
# Validation accuracy: 79.6%
# Minibatch loss at step 1500: 3.498165
# Minibatch accuracy: 84.4%
# Validation accuracy: 79.5%
# Minibatch loss at step 2000: 4.365813
# Minibatch accuracy: 85.2%
# Validation accuracy: 78.5%
# Minibatch loss at step 2500: 4.535096
# Minibatch accuracy: 76.6%
# Validation accuracy: 81.3%
# Minibatch loss at step 3000: 5.301297
# Minibatch accuracy: 79.7%
# Validation accuracy: 81.5%
# Test accuracy: 88.3%
# >> trying learning rate of 0.00030000000000000003
# Initialized
# Minibatch loss at step 0: 391.864044
# Minibatch accuracy: 10.2%
# Validation accuracy: 28.4%
# Minibatch loss at step 500: 8.159176
# Minibatch accuracy: 82.0%
# Validation accuracy: 81.3%
# Minibatch loss at step 1000: 6.077293
# Minibatch accuracy: 74.2%
# Validation accuracy: 79.3%
# Minibatch loss at step 1500: 5.414014
# Minibatch accuracy: 83.6%
# Validation accuracy: 80.5%
# Minibatch loss at step 2000: 4.214884
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.7%
# Minibatch loss at step 2500: 5.598389
# Minibatch accuracy: 78.9%
# Validation accuracy: 79.6%
# Minibatch loss at step 3000: 2.727806
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.1%
# Test accuracy: 88.0%
# >> trying learning rate of 0.0004
# Initialized
# Minibatch loss at step 0: 322.206024
# Minibatch accuracy: 15.6%
# Validation accuracy: 33.4%
# Minibatch loss at step 500: 16.287376
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.4%
# Minibatch loss at step 1000: 7.969766
# Minibatch accuracy: 78.9%
# Validation accuracy: 78.6%
# Minibatch loss at step 1500: 5.206341
# Minibatch accuracy: 84.4%
# Validation accuracy: 80.2%
# Minibatch loss at step 2000: 3.907624
# Minibatch accuracy: 79.7%
# Validation accuracy: 81.1%
# Minibatch loss at step 2500: 5.847648
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.2%
# Minibatch loss at step 3000: 3.141993
# Minibatch accuracy: 86.7%
# Validation accuracy: 81.8%
# Test accuracy: 88.3%
# >> trying learning rate of 0.0005
# Initialized
# Minibatch loss at step 0: 366.668060
# Minibatch accuracy: 8.6%
# Validation accuracy: 32.3%
# Minibatch loss at step 500: 10.742926
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.4%
# Minibatch loss at step 1000: 11.073298
# Minibatch accuracy: 75.8%
# Validation accuracy: 78.9%
# Minibatch loss at step 1500: 4.017097
# Minibatch accuracy: 85.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 2000: 3.898431
# Minibatch accuracy: 82.0%
# Validation accuracy: 81.0%
# Minibatch loss at step 2500: 3.842232
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.4%
# Minibatch loss at step 3000: 3.279867
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.3%
# Test accuracy: 88.4%
# >> trying learning rate of 0.0006000000000000001
# Initialized
# Minibatch loss at step 0: 267.072571
# Minibatch accuracy: 12.5%
# Validation accuracy: 35.1%
# Minibatch loss at step 500: 11.358763
# Minibatch accuracy: 79.7%
# Validation accuracy: 80.4%
# Minibatch loss at step 1000: 8.301960
# Minibatch accuracy: 78.1%
# Validation accuracy: 79.4%
# Minibatch loss at step 1500: 5.623787
# Minibatch accuracy: 88.3%
# Validation accuracy: 80.5%
# Minibatch loss at step 2000: 6.357891
# Minibatch accuracy: 77.3%
# Validation accuracy: 81.3%
# Minibatch loss at step 2500: 5.355240
# Minibatch accuracy: 79.7%
# Validation accuracy: 81.3%
# Minibatch loss at step 3000: 3.966462
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.3%
# Test accuracy: 88.2%
# >> trying learning rate of 0.0007000000000000001
# Initialized
# Minibatch loss at step 0: 412.498718
# Minibatch accuracy: 3.9%
# Validation accuracy: 33.9%
# Minibatch loss at step 500: 10.668670
# Minibatch accuracy: 73.4%
# Validation accuracy: 80.4%
# Minibatch loss at step 1000: 7.287277
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 1500: 4.230500
# Minibatch accuracy: 89.1%
# Validation accuracy: 80.6%
# Minibatch loss at step 2000: 4.736481
# Minibatch accuracy: 80.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 2500: 6.629581
# Minibatch accuracy: 75.8%
# Validation accuracy: 82.3%
# Minibatch loss at step 3000: 2.767073
# Minibatch accuracy: 85.2%
# Validation accuracy: 82.1%
# Test accuracy: 89.1%
# >> trying learning rate of 0.0008
# Initialized
# Minibatch loss at step 0: 394.844391
# Minibatch accuracy: 7.8%
# Validation accuracy: 29.3%
# Minibatch loss at step 500: 9.162489
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.0%
# Minibatch loss at step 1000: 11.253784
# Minibatch accuracy: 77.3%
# Validation accuracy: 78.7%
# Minibatch loss at step 1500: 4.149034
# Minibatch accuracy: 83.6%
# Validation accuracy: 80.0%
# Minibatch loss at step 2000: 6.672465
# Minibatch accuracy: 82.0%
# Validation accuracy: 78.5%
# Minibatch loss at step 2500: 3.980407
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.3%
# Minibatch loss at step 3000: 2.074610
# Minibatch accuracy: 82.8%
# Validation accuracy: 80.4%
# Test accuracy: 87.5%
# >> trying learning rate of 0.0009000000000000001
# Initialized
# Minibatch loss at step 0: 337.253662
# Minibatch accuracy: 11.7%
# Validation accuracy: 27.4%
# Minibatch loss at step 500: 10.537186
# Minibatch accuracy: 76.6%
# Validation accuracy: 81.6%
# Minibatch loss at step 1000: 9.800213
# Minibatch accuracy: 75.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 1500: 5.364900
# Minibatch accuracy: 85.2%
# Validation accuracy: 80.6%
# Minibatch loss at step 2000: 4.485991
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 2500: 5.112886
# Minibatch accuracy: 78.1%
# Validation accuracy: 78.8%
# Minibatch loss at step 3000: 3.318324
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.6%
# Test accuracy: 88.3%

# %% [markdown]
# ### trying two layer neural network

# %%
batch_size = 128
beta = 0.001

hidden_nodes1 = 1024
hidden_nodes2 = 512

graph = tf.Graph()
with graph.as_default():

    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # new hidden layer 1
    
    hidden_weights = tf.Variable( tf.truncated_normal([image_size * image_size, hidden_nodes1]) )
    hidden_biases = tf.Variable( tf.zeros([hidden_nodes1]))
    hidden_layer = tf.nn.relu( tf.matmul( tf_train_dataset, hidden_weights) + hidden_biases)
    
    # add dropout on hidden layer
    keep_prob = tf.placeholder("float")
    hidden_layer_drop = tf.nn.dropout(hidden_layer, keep_prob)
    
    # new hidden layer 2
    hidden_weights2 = tf.Variable( tf.truncated_normal([hidden_nodes1, hidden_nodes2]) )
    hidden_biases2 = tf.Variable( tf.zeros([hidden_nodes2]))
    hidden_layer2 = tf.nn.relu( tf.matmul( hidden_layer_drop, hidden_weights2) + hidden_biases2)
    
    # add dropout on hidden layer
    hidden_layer_drop2 = tf.nn.dropout(hidden_layer2, keep_prob)
    
    # Variables.
    weights = tf.Variable( tf.truncated_normal([hidden_nodes2, num_labels])) 
    biases = tf.Variable(tf.zeros([num_labels]))

    # Training computation.
    logits = tf.matmul(hidden_layer_drop2, weights) + biases
    
    loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels) )
    loss = tf.reduce_mean( loss + beta * tf.nn.l2_loss(weights) )

    # Optimizer.
    global_step = tf.Variable(0)  # count the number of steps taken.
    learnr = tf.placeholder("float")
    learning_rate = tf.train.exponential_decay(learnr, global_step, 100000, 0.95, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step= global_step)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)    
    
    valid_relu1 = tf.nn.relu(  tf.matmul(tf_valid_dataset, hidden_weights) + hidden_biases)    
    valid_relu2 = tf.nn.relu(  tf.matmul(valid_relu1, hidden_weights2) + hidden_biases2)    
    
    valid_prediction = tf.nn.softmax( tf.matmul(valid_relu2, weights) + biases) 
    
    test_relu1 = tf.nn.relu( tf.matmul( tf_test_dataset, hidden_weights) + hidden_biases)
    test_relu2 = tf.nn.relu( tf.matmul( test_relu1, hidden_weights2) + hidden_biases2)   
    
    test_prediction = tf.nn.softmax(tf.matmul(test_relu2, weights) + biases)

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob : 1.0, learnr : 0.001}
    _, l, predictions = session.run( [optimizer, loss, train_prediction], feed_dict=feed_dict )
    if (step % 500 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(valid_prediction.eval(), valid_labels))
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 5591.298340
# Minibatch accuracy: 5.5%
# Validation accuracy: 10.2%
# Minibatch loss at step 500: 360.979828
# Minibatch accuracy: 77.3%
# Validation accuracy: 76.1%
# Minibatch loss at step 1000: 197.053528
# Minibatch accuracy: 79.7%
# Validation accuracy: 78.4%
# Minibatch loss at step 1500: 140.675903
# Minibatch accuracy: 86.7%
# Validation accuracy: 79.2%
# Minibatch loss at step 2000: 194.144760
# Minibatch accuracy: 78.9%
# Validation accuracy: 78.6%
# Minibatch loss at step 2500: 190.313065
# Minibatch accuracy: 78.9%
# Validation accuracy: 79.9%
# Minibatch loss at step 3000: 103.133148
# Minibatch accuracy: 83.6%
# Validation accuracy: 80.2%
# Test accuracy: 87.4%

# %%
batch_size = 128
beta = 0.001

hidden_nodes1 = 1024
hidden_nodes2 = 512

graph = tf.Graph()
with graph.as_default():

    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # new hidden layer 1
    
    hidden_weights = tf.Variable( tf.truncated_normal([image_size * image_size, hidden_nodes1]) )
    hidden_biases = tf.Variable( tf.zeros([hidden_nodes1]))
    hidden_layer = tf.nn.relu( tf.matmul( tf_train_dataset, hidden_weights) + hidden_biases)
    
    # add dropout on hidden layer
    keep_prob = tf.placeholder("float")
    hidden_layer_drop = tf.nn.dropout(hidden_layer, keep_prob)
    
    # new hidden layer 2
    hidden_weights2 = tf.Variable( tf.truncated_normal([hidden_nodes1, hidden_nodes2]) )
    hidden_biases2 = tf.Variable( tf.zeros([hidden_nodes2]))
    hidden_layer2 = tf.nn.relu( tf.matmul( hidden_layer_drop, hidden_weights2) + hidden_biases2)
    
    # add dropout on hidden layer
    hidden_layer_drop2 = tf.nn.dropout(hidden_layer2, keep_prob)
    
    # Variables.
    weights = tf.Variable( tf.truncated_normal([hidden_nodes2, num_labels])) 
    biases = tf.Variable(tf.zeros([num_labels]))

    # Training computation.
    logits = tf.matmul(hidden_layer_drop2, weights) + biases
    
    loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits = logits,labels= tf_train_labels) )
    loss = tf.reduce_mean( loss + beta * tf.nn.l2_loss(weights) )

    # Optimizer.
    global_step = tf.Variable(0)  # count the number of steps taken.
    learnr = tf.placeholder("float")
    learning_rate = tf.train.exponential_decay(learnr, global_step, 100000, 0.95, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step= global_step)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)    
    
    valid_relu1 = tf.nn.relu(  tf.matmul(tf_valid_dataset, hidden_weights) + hidden_biases)    
    valid_relu2 = tf.nn.relu(  tf.matmul(valid_relu1, hidden_weights2) + hidden_biases2)    
    
    valid_prediction = tf.nn.softmax( tf.matmul(valid_relu2, weights) + biases) 
    
    test_relu1 = tf.nn.relu( tf.matmul( tf_test_dataset, hidden_weights) + hidden_biases)
    test_relu2 = tf.nn.relu( tf.matmul( test_relu1, hidden_weights2) + hidden_biases2)   
    
    test_prediction = tf.nn.softmax(tf.matmul(test_relu2, weights) + biases)

# %%
num_steps = 3001
scores = {}
for kp in [0.5, 0.6, 0.7, 0.9, 0.9, 1.0]:
    for lr in np.arange(0.0001, 0.001, 0.0001).tolist():
        print(">> with keep prob of " + str(kp))
        print(">> with learning rate  " + str(lr))
        with tf.Session(graph=graph) as session:
          tf.initialize_all_variables().run()
          print("Initialized")
          for step in range(num_steps):
            # Pick an offset within the training data, which has been randomized.
            # Note: we could use better randomization across epochs.
            offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
            # Generate a minibatch.
            batch_data = train_dataset[offset:(offset + batch_size), :]
            batch_labels = train_labels[offset:(offset + batch_size), :]
            # Prepare a dictionary telling the session where to feed the minibatch.
            # The key of the dictionary is the placeholder node of the graph to be fed,
            # and the value is the numpy array to feed to it.
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob : kp, learnr : lr}
            _, l, predictions = session.run( [optimizer, loss, train_prediction], feed_dict=feed_dict )
            if (step % 500 == 0):
              print("Minibatch loss at step %d: %f" % (step, l))
              print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
              print("Validation accuracy: %.1f%%" % accuracy(valid_prediction.eval(), valid_labels))
          acc = accuracy(test_prediction.eval(), test_labels)
          scores[(kp, lr)] = acc
          print("Test accuracy: %.1f%%" % acc)
print(scores)
# Out:
# >> with keep prob of 0.5
# >> with learning rate  0.0001
# Initialized
# Minibatch loss at step 0: 10255.742188
# Minibatch accuracy: 9.4%
# Validation accuracy: 12.8%
# Minibatch loss at step 500: 3285.767090
# Minibatch accuracy: 45.3%
# Validation accuracy: 70.3%
# Minibatch loss at step 1000: 1768.007324
# Minibatch accuracy: 55.5%
# Validation accuracy: 75.3%
# Minibatch loss at step 1500: 1532.116699
# Minibatch accuracy: 60.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 2000: 1514.243164
# Minibatch accuracy: 55.5%
# Validation accuracy: 78.5%
# Minibatch loss at step 2500: 1642.928711
# Minibatch accuracy: 58.6%
# Validation accuracy: 79.0%
# Minibatch loss at step 3000: 1280.700317
# Minibatch accuracy: 65.6%
# Validation accuracy: 79.5%
# Test accuracy: 86.5%
# >> with keep prob of 0.5
# >> with learning rate  0.0002
# Initialized
# Minibatch loss at step 0: 9713.031250
# Minibatch accuracy: 5.5%
# Validation accuracy: 5.6%
# Minibatch loss at step 500: 2307.656494
# Minibatch accuracy: 48.4%
# Validation accuracy: 74.9%
# Minibatch loss at step 1000: 1786.261353
# Minibatch accuracy: 53.9%
# Validation accuracy: 77.9%
# Minibatch loss at step 1500: 512.153015
# Minibatch accuracy: 73.4%
# Validation accuracy: 79.1%
# Minibatch loss at step 2000: 958.837830
# Minibatch accuracy: 67.2%
# Validation accuracy: 79.5%
# Minibatch loss at step 2500: 690.034973
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 3000: 735.455872
# Minibatch accuracy: 64.8%
# Validation accuracy: 80.0%
# Test accuracy: 87.4%
# >> with keep prob of 0.5
# >> with learning rate  0.00030000000000000003
# Initialized
# Minibatch loss at step 0: 10383.470703
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.4%
# Minibatch loss at step 500: 2249.109619
# Minibatch accuracy: 46.1%
# Validation accuracy: 75.7%
# Minibatch loss at step 1000: 1536.964600
# Minibatch accuracy: 59.4%
# Validation accuracy: 78.2%
# Minibatch loss at step 1500: 748.939941
# Minibatch accuracy: 71.9%
# Validation accuracy: 79.0%
# Minibatch loss at step 2000: 847.085999
# Minibatch accuracy: 67.2%
# Validation accuracy: 79.1%
# Minibatch loss at step 2500: 739.309998
# Minibatch accuracy: 69.5%
# Validation accuracy: 79.9%
# Minibatch loss at step 3000: 530.300232
# Minibatch accuracy: 70.3%
# Validation accuracy: 80.1%
# Test accuracy: 87.7%
# >> with keep prob of 0.5
# >> with learning rate  0.0004
# Initialized
# Minibatch loss at step 0: 8737.067383
# Minibatch accuracy: 10.2%
# Validation accuracy: 19.0%
# Minibatch loss at step 500: 1457.197876
# Minibatch accuracy: 57.0%
# Validation accuracy: 77.3%
# Minibatch loss at step 1000: 1039.834351
# Minibatch accuracy: 60.9%
# Validation accuracy: 79.2%
# Minibatch loss at step 1500: 515.817444
# Minibatch accuracy: 73.4%
# Validation accuracy: 79.9%
# Minibatch loss at step 2000: 660.765625
# Minibatch accuracy: 67.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 2500: 593.485046
# Minibatch accuracy: 65.6%
# Validation accuracy: 80.2%
# Minibatch loss at step 3000: 415.480469
# Minibatch accuracy: 64.1%
# Validation accuracy: 80.6%
# Test accuracy: 87.9%
# >> with keep prob of 0.5
# >> with learning rate  0.0005
# Initialized
# Minibatch loss at step 0: 10469.732422
# Minibatch accuracy: 7.8%
# Validation accuracy: 9.1%
# Minibatch loss at step 500: 1656.182617
# Minibatch accuracy: 57.0%
# Validation accuracy: 78.5%
# Minibatch loss at step 1000: 1090.320068
# Minibatch accuracy: 61.7%
# Validation accuracy: 79.7%
# Minibatch loss at step 1500: 307.432312
# Minibatch accuracy: 76.6%
# Validation accuracy: 80.6%
# Minibatch loss at step 2000: 432.430420
# Minibatch accuracy: 67.2%
# Validation accuracy: 80.3%
# Minibatch loss at step 2500: 347.613312
# Minibatch accuracy: 69.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 3000: 244.582275
# Minibatch accuracy: 71.9%
# Validation accuracy: 80.6%
# Test accuracy: 87.7%
# >> with keep prob of 0.5
# >> with learning rate  0.0006000000000000001
# Initialized
# Minibatch loss at step 0: 10179.801758
# Minibatch accuracy: 10.2%
# Validation accuracy: 6.4%
# Minibatch loss at step 500: 1638.419678
# Minibatch accuracy: 53.9%
# Validation accuracy: 78.3%
# Minibatch loss at step 1000: 797.242004
# Minibatch accuracy: 63.3%
# Validation accuracy: 79.8%
# Minibatch loss at step 1500: 447.138428
# Minibatch accuracy: 72.7%
# Validation accuracy: 80.3%
# Minibatch loss at step 2000: 378.847504
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.4%
# Minibatch loss at step 2500: 262.141907
# Minibatch accuracy: 73.4%
# Validation accuracy: 79.6%
# Minibatch loss at step 3000: 175.564240
# Minibatch accuracy: 70.3%
# Validation accuracy: 80.2%
# Test accuracy: 87.3%
# >> with keep prob of 0.5
# >> with learning rate  0.0007000000000000001
# Initialized
# Minibatch loss at step 0: 9350.591797
# Minibatch accuracy: 7.8%
# Validation accuracy: 11.6%
# Minibatch loss at step 500: 1091.709229
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.0%
# Minibatch loss at step 1000: 629.799683
# Minibatch accuracy: 63.3%
# Validation accuracy: 80.1%
# Minibatch loss at step 1500: 293.798248
# Minibatch accuracy: 76.6%
# Validation accuracy: 80.4%
# Minibatch loss at step 2000: 413.361694
# Minibatch accuracy: 65.6%
# Validation accuracy: 80.8%
# Minibatch loss at step 2500: 233.647232
# Minibatch accuracy: 67.2%
# Validation accuracy: 80.3%
# Minibatch loss at step 3000: 173.674698
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.3%
# Test accuracy: 87.4%
# >> with keep prob of 0.5
# >> with learning rate  0.0008
# Initialized
# Minibatch loss at step 0: 10116.468750
# Minibatch accuracy: 8.6%
# Validation accuracy: 12.4%
# Minibatch loss at step 500: 1071.459473
# Minibatch accuracy: 59.4%
# Validation accuracy: 79.6%
# Minibatch loss at step 1000: 616.786072
# Minibatch accuracy: 64.1%
# Validation accuracy: 80.2%
# Minibatch loss at step 1500: 245.824921
# Minibatch accuracy: 73.4%
# Validation accuracy: 80.7%
# Minibatch loss at step 2000: 249.142105
# Minibatch accuracy: 72.7%
# Validation accuracy: 80.1%
# Minibatch loss at step 2500: 229.014786
# Minibatch accuracy: 67.2%
# Validation accuracy: 80.6%
# Minibatch loss at step 3000: 140.871536
# Minibatch accuracy: 71.9%
# Validation accuracy: 80.9%
# Test accuracy: 87.6%
# >> with keep prob of 0.5
# >> with learning rate  0.0009000000000000001
# Initialized
# Minibatch loss at step 0: 7576.813965
# Minibatch accuracy: 11.7%
# Validation accuracy: 13.0%
# Minibatch loss at step 500: 826.876343
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 1000: 394.742432
# Minibatch accuracy: 71.1%
# Validation accuracy: 81.0%
# Minibatch loss at step 1500: 232.767441
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.9%
# Minibatch loss at step 2000: 232.606522
# Minibatch accuracy: 70.3%
# Validation accuracy: 80.5%
# Minibatch loss at step 2500: 144.875916
# Minibatch accuracy: 65.6%
# Validation accuracy: 80.3%
# Minibatch loss at step 3000: 111.127380
# Minibatch accuracy: 64.8%
# Validation accuracy: 80.0%
# Test accuracy: 86.6%
# >> with keep prob of 0.6
# >> with learning rate  0.0001
# Initialized
# Minibatch loss at step 0: 8151.616211
# Minibatch accuracy: 9.4%
# Validation accuracy: 11.7%
# Minibatch loss at step 500: 2573.667725
# Minibatch accuracy: 45.3%
# Validation accuracy: 70.9%
# Minibatch loss at step 1000: 1930.227905
# Minibatch accuracy: 56.2%
# Validation accuracy: 75.5%
# Minibatch loss at step 1500: 942.554138
# Minibatch accuracy: 61.7%
# Validation accuracy: 77.3%
# Minibatch loss at step 2000: 1190.524170
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.1%
# Minibatch loss at step 2500: 1109.372803
# Minibatch accuracy: 67.2%
# Validation accuracy: 78.6%
# Minibatch loss at step 3000: 1167.109375
# Minibatch accuracy: 65.6%
# Validation accuracy: 79.0%
# Test accuracy: 86.7%
# >> with keep prob of 0.6
# >> with learning rate  0.0002
# Initialized
# Minibatch loss at step 0: 8500.778320
# Minibatch accuracy: 13.3%
# Validation accuracy: 10.7%
# Minibatch loss at step 500: 1613.819458
# Minibatch accuracy: 48.4%
# Validation accuracy: 75.7%
# Minibatch loss at step 1000: 1126.768188
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.3%
# Minibatch loss at step 1500: 637.910706
# Minibatch accuracy: 77.3%
# Validation accuracy: 79.2%
# Minibatch loss at step 2000: 1003.363464
# Minibatch accuracy: 65.6%
# Validation accuracy: 79.9%
# Minibatch loss at step 2500: 917.340881
# Minibatch accuracy: 68.0%
# Validation accuracy: 80.2%
# Minibatch loss at step 3000: 618.311646
# Minibatch accuracy: 64.8%
# Validation accuracy: 80.7%
# Test accuracy: 87.5%
# >> with keep prob of 0.6
# >> with learning rate  0.00030000000000000003
# Initialized
# Minibatch loss at step 0: 8055.793457
# Minibatch accuracy: 7.8%
# Validation accuracy: 9.4%
# Minibatch loss at step 500: 1408.159302
# Minibatch accuracy: 60.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 1000: 970.783386
# Minibatch accuracy: 64.1%
# Validation accuracy: 79.3%
# Minibatch loss at step 1500: 559.201172
# Minibatch accuracy: 74.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 2000: 801.077515
# Minibatch accuracy: 70.3%
# Validation accuracy: 80.4%
# Minibatch loss at step 2500: 803.508301
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.7%
# Minibatch loss at step 3000: 552.789185
# Minibatch accuracy: 71.1%
# Validation accuracy: 81.1%
# Test accuracy: 87.8%
# >> with keep prob of 0.6
# >> with learning rate  0.0004
# Initialized
# Minibatch loss at step 0: 7368.016602
# Minibatch accuracy: 9.4%
# Validation accuracy: 10.6%
# Minibatch loss at step 500: 1265.839844
# Minibatch accuracy: 57.0%
# Validation accuracy: 78.0%
# Minibatch loss at step 1000: 956.933655
# Minibatch accuracy: 66.4%
# Validation accuracy: 79.7%
# Minibatch loss at step 1500: 367.532745
# Minibatch accuracy: 74.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 2000: 568.625244
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.8%
# Minibatch loss at step 2500: 476.940125
# Minibatch accuracy: 64.1%
# Validation accuracy: 80.9%
# Minibatch loss at step 3000: 370.731476
# Minibatch accuracy: 68.0%
# Validation accuracy: 80.9%
# Test accuracy: 88.2%
# >> with keep prob of 0.6
# >> with learning rate  0.0005
# Initialized
# Minibatch loss at step 0: 7215.822266
# Minibatch accuracy: 16.4%
# Validation accuracy: 13.3%
# Minibatch loss at step 500: 1593.875732
# Minibatch accuracy: 53.9%
# Validation accuracy: 78.5%
# Minibatch loss at step 1000: 738.934326
# Minibatch accuracy: 68.0%
# Validation accuracy: 79.9%
# Minibatch loss at step 1500: 404.235413
# Minibatch accuracy: 72.7%
# Validation accuracy: 80.6%
# Minibatch loss at step 2000: 384.473297
# Minibatch accuracy: 78.1%
# Validation accuracy: 80.8%
# Minibatch loss at step 2500: 414.776855
# Minibatch accuracy: 64.1%
# Validation accuracy: 80.9%
# Minibatch loss at step 3000: 268.928284
# Minibatch accuracy: 72.7%
# Validation accuracy: 80.9%
# Test accuracy: 88.0%
# >> with keep prob of 0.6
# >> with learning rate  0.0006000000000000001
# Initialized
# Minibatch loss at step 0: 6641.755859
# Minibatch accuracy: 7.0%
# Validation accuracy: 11.4%
# Minibatch loss at step 500: 1147.079590
# Minibatch accuracy: 64.1%
# Validation accuracy: 78.9%
# Minibatch loss at step 1000: 670.267151
# Minibatch accuracy: 67.2%
# Validation accuracy: 80.1%
# Minibatch loss at step 1500: 347.048676
# Minibatch accuracy: 74.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 2000: 385.514832
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.0%
# Minibatch loss at step 2500: 336.961578
# Minibatch accuracy: 71.9%
# Validation accuracy: 80.9%
# Minibatch loss at step 3000: 220.379105
# Minibatch accuracy: 71.1%
# Validation accuracy: 81.0%
# Test accuracy: 87.9%
# >> with keep prob of 0.6
# >> with learning rate  0.0007000000000000001
# Initialized
# Minibatch loss at step 0: 8834.741211
# Minibatch accuracy: 7.8%
# Validation accuracy: 8.7%
# Minibatch loss at step 500: 1126.212891
# Minibatch accuracy: 61.7%
# Validation accuracy: 79.6%
# Minibatch loss at step 1000: 623.010315
# Minibatch accuracy: 61.7%
# Validation accuracy: 80.4%
# Minibatch loss at step 1500: 222.451935
# Minibatch accuracy: 78.1%
# Validation accuracy: 80.7%
# Minibatch loss at step 2000: 335.483826
# Minibatch accuracy: 71.9%
# Validation accuracy: 81.1%
# Minibatch loss at step 2500: 306.932831
# Minibatch accuracy: 68.0%
# Validation accuracy: 80.7%
# Minibatch loss at step 3000: 151.029678
# Minibatch accuracy: 77.3%
# Validation accuracy: 80.5%
# Test accuracy: 87.8%
# >> with keep prob of 0.6
# >> with learning rate  0.0008
# Initialized
# Minibatch loss at step 0: 7839.057129
# Minibatch accuracy: 11.7%
# Validation accuracy: 13.4%
# Minibatch loss at step 500: 782.088318
# Minibatch accuracy: 64.8%
# Validation accuracy: 79.1%
# Minibatch loss at step 1000: 443.809296
# Minibatch accuracy: 71.9%
# Validation accuracy: 80.2%
# Minibatch loss at step 1500: 211.995499
# Minibatch accuracy: 78.9%
# Validation accuracy: 80.6%
# Minibatch loss at step 2000: 308.265167
# Minibatch accuracy: 64.8%
# Validation accuracy: 80.8%
# Minibatch loss at step 2500: 201.344650
# Minibatch accuracy: 71.9%
# Validation accuracy: 80.5%
# Minibatch loss at step 3000: 134.655792
# Minibatch accuracy: 71.9%
# Validation accuracy: 81.0%
# Test accuracy: 88.0%
# >> with keep prob of 0.6
# >> with learning rate  0.0009000000000000001
# Initialized
# Minibatch loss at step 0: 7345.169922
# Minibatch accuracy: 10.2%
# Validation accuracy: 13.1%
# Minibatch loss at step 500: 894.718140
# Minibatch accuracy: 67.2%
# Validation accuracy: 79.5%
# Minibatch loss at step 1000: 482.583191
# Minibatch accuracy: 71.1%
# Validation accuracy: 80.4%
# Minibatch loss at step 1500: 190.899902
# Minibatch accuracy: 74.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 2000: 220.688446
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.9%
# Minibatch loss at step 2500: 194.636398
# Minibatch accuracy: 70.3%
# Validation accuracy: 79.9%
# Minibatch loss at step 3000: 149.041306
# Minibatch accuracy: 59.4%
# Validation accuracy: 80.5%
# Test accuracy: 87.5%
# >> with keep prob of 0.7
# >> with learning rate  0.0001
# Initialized
# Minibatch loss at step 0: 7478.540527
# Minibatch accuracy: 7.0%
# Validation accuracy: 11.6%
# Minibatch loss at step 500: 1828.210327
# Minibatch accuracy: 46.9%
# Validation accuracy: 71.6%
# Minibatch loss at step 1000: 1226.514526
# Minibatch accuracy: 57.8%
# Validation accuracy: 75.7%
# Minibatch loss at step 1500: 845.606079
# Minibatch accuracy: 69.5%
# Validation accuracy: 77.6%
# Minibatch loss at step 2000: 965.268372
# Minibatch accuracy: 64.1%
# Validation accuracy: 78.6%
# Minibatch loss at step 2500: 1290.880493
# Minibatch accuracy: 61.7%
# Validation accuracy: 79.1%
# Minibatch loss at step 3000: 837.312317
# Minibatch accuracy: 70.3%
# Validation accuracy: 79.5%
# Test accuracy: 86.6%
# >> with keep prob of 0.7
# >> with learning rate  0.0002
# Initialized
# Minibatch loss at step 0: 6438.574707
# Minibatch accuracy: 14.1%
# Validation accuracy: 12.9%
# Minibatch loss at step 500: 1240.168213
# Minibatch accuracy: 58.6%
# Validation accuracy: 75.6%
# Minibatch loss at step 1000: 891.788940
# Minibatch accuracy: 71.9%
# Validation accuracy: 78.3%
# Minibatch loss at step 1500: 409.623291
# Minibatch accuracy: 79.7%
# Validation accuracy: 79.1%
# Minibatch loss at step 2000: 600.363647
# Minibatch accuracy: 71.9%
# Validation accuracy: 79.8%
# Minibatch loss at step 2500: 674.622742
# Minibatch accuracy: 67.2%
# Validation accuracy: 80.1%
# Minibatch loss at step 3000: 526.112122
# Minibatch accuracy: 71.9%
# Validation accuracy: 80.4%
# Test accuracy: 87.8%
# >> with keep prob of 0.7
# >> with learning rate  0.00030000000000000003
# Initialized
# Minibatch loss at step 0: 7379.584473
# Minibatch accuracy: 7.8%
# Validation accuracy: 9.8%
# Minibatch loss at step 500: 1395.962769
# Minibatch accuracy: 60.2%
# Validation accuracy: 76.7%
# Minibatch loss at step 1000: 824.514648
# Minibatch accuracy: 66.4%
# Validation accuracy: 78.6%
# Minibatch loss at step 1500: 441.364563
# Minibatch accuracy: 80.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 2000: 660.211792
# Minibatch accuracy: 73.4%
# Validation accuracy: 79.9%
# Minibatch loss at step 2500: 579.201294
# Minibatch accuracy: 68.0%
# Validation accuracy: 80.2%
# Minibatch loss at step 3000: 474.535217
# Minibatch accuracy: 71.9%
# Validation accuracy: 80.6%
# Test accuracy: 88.3%
# >> with keep prob of 0.7
# >> with learning rate  0.0004
# Initialized
# Minibatch loss at step 0: 6764.976562
# Minibatch accuracy: 15.6%
# Validation accuracy: 14.1%
# Minibatch loss at step 500: 1076.571899
# Minibatch accuracy: 61.7%
# Validation accuracy: 78.0%
# Minibatch loss at step 1000: 750.187073
# Minibatch accuracy: 67.2%
# Validation accuracy: 79.9%
# Minibatch loss at step 1500: 326.166290
# Minibatch accuracy: 79.7%
# Validation accuracy: 80.6%
# Minibatch loss at step 2000: 431.987183
# Minibatch accuracy: 78.9%
# Validation accuracy: 81.1%
# Minibatch loss at step 2500: 428.788605
# Minibatch accuracy: 70.3%
# Validation accuracy: 81.0%
# Minibatch loss at step 3000: 365.189606
# Minibatch accuracy: 75.8%
# Validation accuracy: 80.9%
# Test accuracy: 88.1%
# >> with keep prob of 0.7
# >> with learning rate  0.0005
# Initialized
# Minibatch loss at step 0: 7638.835938
# Minibatch accuracy: 10.9%
# Validation accuracy: 9.3%
# Minibatch loss at step 500: 977.378906
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 1000: 562.237427
# Minibatch accuracy: 69.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 1500: 316.937744
# Minibatch accuracy: 76.6%
# Validation accuracy: 80.7%
# Minibatch loss at step 2000: 465.422119
# Minibatch accuracy: 69.5%
# Validation accuracy: 80.5%
# Minibatch loss at step 2500: 401.451782
# Minibatch accuracy: 71.1%
# Validation accuracy: 80.8%
# Minibatch loss at step 3000: 272.632294
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.2%
# Test accuracy: 87.9%
# >> with keep prob of 0.7
# >> with learning rate  0.0006000000000000001
# Initialized
# Minibatch loss at step 0: 6635.467285
# Minibatch accuracy: 4.7%
# Validation accuracy: 10.3%
# Minibatch loss at step 500: 877.913147
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.3%
# Minibatch loss at step 1000: 471.596985
# Minibatch accuracy: 68.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 1500: 252.216537
# Minibatch accuracy: 85.2%
# Validation accuracy: 81.0%
# Minibatch loss at step 2000: 329.405762
# Minibatch accuracy: 73.4%
# Validation accuracy: 81.6%
# Minibatch loss at step 2500: 405.870087
# Minibatch accuracy: 70.3%
# Validation accuracy: 81.6%
# Minibatch loss at step 3000: 220.034882
# Minibatch accuracy: 75.8%
# Validation accuracy: 81.6%
# Test accuracy: 88.3%
# >> with keep prob of 0.7
# >> with learning rate  0.0007000000000000001
# Initialized
# Minibatch loss at step 0: 7303.531738
# Minibatch accuracy: 9.4%
# Validation accuracy: 12.7%
# Minibatch loss at step 500: 818.036926
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 1000: 534.678955
# Minibatch accuracy: 71.9%
# Validation accuracy: 80.4%
# Minibatch loss at step 1500: 172.058746
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.1%
# Minibatch loss at step 2000: 365.351868
# Minibatch accuracy: 72.7%
# Validation accuracy: 81.0%
# Minibatch loss at step 2500: 306.350220
# Minibatch accuracy: 68.0%
# Validation accuracy: 81.1%
# Minibatch loss at step 3000: 165.266235
# Minibatch accuracy: 77.3%
# Validation accuracy: 81.1%
# Test accuracy: 88.6%
# >> with keep prob of 0.7
# >> with learning rate  0.0008
# Initialized
# Minibatch loss at step 0: 6602.298340
# Minibatch accuracy: 7.0%
# Validation accuracy: 8.1%
# Minibatch loss at step 500: 803.441833
# Minibatch accuracy: 69.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 1000: 544.927246
# Minibatch accuracy: 67.2%
# Validation accuracy: 80.4%
# Minibatch loss at step 1500: 272.401794
# Minibatch accuracy: 76.6%
# Validation accuracy: 80.9%
# Minibatch loss at step 2000: 333.834381
# Minibatch accuracy: 68.0%
# Validation accuracy: 80.8%
# Minibatch loss at step 2500: 233.818909
# Minibatch accuracy: 70.3%
# Validation accuracy: 81.1%
# Minibatch loss at step 3000: 198.647537
# Minibatch accuracy: 76.6%
# Validation accuracy: 80.8%
# Test accuracy: 88.3%
# >> with keep prob of 0.7
# >> with learning rate  0.0009000000000000001
# Initialized
# Minibatch loss at step 0: 6835.861328
# Minibatch accuracy: 12.5%
# Validation accuracy: 12.1%
# Minibatch loss at step 500: 799.771790
# Minibatch accuracy: 63.3%
# Validation accuracy: 80.3%
# Minibatch loss at step 1000: 440.051025
# Minibatch accuracy: 76.6%
# Validation accuracy: 80.7%
# Minibatch loss at step 1500: 165.245453
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.1%
# Minibatch loss at step 2000: 256.395752
# Minibatch accuracy: 72.7%
# Validation accuracy: 81.0%
# Minibatch loss at step 2500: 236.456299
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.3%
# Minibatch loss at step 3000: 132.765533
# Minibatch accuracy: 69.5%
# Validation accuracy: 81.0%
# Test accuracy: 88.2%
# >> with keep prob of 0.9
# >> with learning rate  0.0001
# Initialized
# Minibatch loss at step 0: 4376.159180
# Minibatch accuracy: 15.6%
# Validation accuracy: 11.5%
# Minibatch loss at step 500: 1018.691589
# Minibatch accuracy: 54.7%
# Validation accuracy: 69.7%
# Minibatch loss at step 1000: 863.131653
# Minibatch accuracy: 68.0%
# Validation accuracy: 74.2%
# Minibatch loss at step 1500: 273.295837
# Minibatch accuracy: 83.6%
# Validation accuracy: 76.3%
# Minibatch loss at step 2000: 649.809998
# Minibatch accuracy: 71.9%
# Validation accuracy: 77.1%
# Minibatch loss at step 2500: 545.769897
# Minibatch accuracy: 73.4%
# Validation accuracy: 77.8%
# Minibatch loss at step 3000: 572.064026
# Minibatch accuracy: 72.7%
# Validation accuracy: 78.3%
# Test accuracy: 86.2%
# >> with keep prob of 0.9
# >> with learning rate  0.0002
# Initialized
# Minibatch loss at step 0: 5767.411621
# Minibatch accuracy: 13.3%
# Validation accuracy: 8.5%
# Minibatch loss at step 500: 896.848450
# Minibatch accuracy: 64.8%
# Validation accuracy: 74.0%
# Minibatch loss at step 1000: 664.295349
# Minibatch accuracy: 66.4%
# Validation accuracy: 77.2%
# Minibatch loss at step 1500: 401.164337
# Minibatch accuracy: 79.7%
# Validation accuracy: 78.3%
# Minibatch loss at step 2000: 431.737030
# Minibatch accuracy: 74.2%
# Validation accuracy: 79.3%
# Minibatch loss at step 2500: 550.048706
# Minibatch accuracy: 74.2%
# Validation accuracy: 79.8%
# Minibatch loss at step 3000: 343.728760
# Minibatch accuracy: 78.9%
# Validation accuracy: 80.1%
# Test accuracy: 87.2%
# >> with keep prob of 0.9
# >> with learning rate  0.00030000000000000003
# Initialized
# Minibatch loss at step 0: 4956.775391
# Minibatch accuracy: 14.1%
# Validation accuracy: 9.7%
# Minibatch loss at step 500: 926.423462
# Minibatch accuracy: 66.4%
# Validation accuracy: 76.7%
# Minibatch loss at step 1000: 532.736328
# Minibatch accuracy: 73.4%
# Validation accuracy: 78.6%
# Minibatch loss at step 1500: 278.654388
# Minibatch accuracy: 80.5%
# Validation accuracy: 79.6%
# Minibatch loss at step 2000: 475.208527
# Minibatch accuracy: 75.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 2500: 416.996338
# Minibatch accuracy: 74.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 3000: 376.584991
# Minibatch accuracy: 74.2%
# Validation accuracy: 80.8%
# Test accuracy: 87.7%
# >> with keep prob of 0.9
# >> with learning rate  0.0004
# Initialized
# Minibatch loss at step 0: 4733.552246
# Minibatch accuracy: 11.7%
# Validation accuracy: 16.0%
# Minibatch loss at step 500: 611.801758
# Minibatch accuracy: 67.2%
# Validation accuracy: 77.4%
# Minibatch loss at step 1000: 453.927521
# Minibatch accuracy: 77.3%
# Validation accuracy: 79.2%
# Minibatch loss at step 1500: 325.662994
# Minibatch accuracy: 82.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 2000: 376.472107
# Minibatch accuracy: 74.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 2500: 341.883545
# Minibatch accuracy: 76.6%
# Validation accuracy: 80.8%
# Minibatch loss at step 3000: 235.856110
# Minibatch accuracy: 82.0%
# Validation accuracy: 81.2%
# Test accuracy: 88.4%
# >> with keep prob of 0.9
# >> with learning rate  0.0005
# Initialized
# Minibatch loss at step 0: 4875.172852
# Minibatch accuracy: 13.3%
# Validation accuracy: 8.8%
# Minibatch loss at step 500: 657.224670
# Minibatch accuracy: 73.4%
# Validation accuracy: 77.8%
# Minibatch loss at step 1000: 478.589142
# Minibatch accuracy: 72.7%
# Validation accuracy: 79.4%
# Minibatch loss at step 1500: 174.159149
# Minibatch accuracy: 85.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 2000: 337.871552
# Minibatch accuracy: 71.1%
# Validation accuracy: 80.5%
# Minibatch loss at step 2500: 318.196625
# Minibatch accuracy: 73.4%
# Validation accuracy: 80.6%
# Minibatch loss at step 3000: 274.494476
# Minibatch accuracy: 78.1%
# Validation accuracy: 80.7%
# Test accuracy: 87.8%
# >> with keep prob of 0.9
# >> with learning rate  0.0006000000000000001
# Initialized
# Minibatch loss at step 0: 5065.031250
# Minibatch accuracy: 13.3%
# Validation accuracy: 13.8%
# Minibatch loss at step 500: 520.362488
# Minibatch accuracy: 73.4%
# Validation accuracy: 78.2%
# Minibatch loss at step 1000: 463.569183
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.8%
# Minibatch loss at step 1500: 224.003113
# Minibatch accuracy: 85.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 2000: 282.440613
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.7%
# Minibatch loss at step 2500: 297.869049
# Minibatch accuracy: 72.7%
# Validation accuracy: 80.8%
# Minibatch loss at step 3000: 173.104218
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.2%
# Test accuracy: 88.4%
# >> with keep prob of 0.9
# >> with learning rate  0.0007000000000000001
# Initialized
# Minibatch loss at step 0: 6010.247559
# Minibatch accuracy: 11.7%
# Validation accuracy: 12.0%
# Minibatch loss at step 500: 655.254517
# Minibatch accuracy: 68.0%
# Validation accuracy: 78.5%
# Minibatch loss at step 1000: 362.060211
# Minibatch accuracy: 73.4%
# Validation accuracy: 80.0%
# Minibatch loss at step 1500: 181.248505
# Minibatch accuracy: 86.7%
# Validation accuracy: 80.6%
# Minibatch loss at step 2000: 266.221893
# Minibatch accuracy: 77.3%
# Validation accuracy: 80.8%
# Minibatch loss at step 2500: 284.595520
# Minibatch accuracy: 75.8%
# Validation accuracy: 81.2%
# Minibatch loss at step 3000: 140.987610
# Minibatch accuracy: 82.0%
# Validation accuracy: 81.3%
# Test accuracy: 88.1%
# >> with keep prob of 0.9
# >> with learning rate  0.0008
# Initialized
# Minibatch loss at step 0: 6331.291504
# Minibatch accuracy: 12.5%
# Validation accuracy: 11.1%
# Minibatch loss at step 500: 672.411926
# Minibatch accuracy: 67.2%
# Validation accuracy: 78.8%
# Minibatch loss at step 1000: 293.635803
# Minibatch accuracy: 76.6%
# Validation accuracy: 79.9%
# Minibatch loss at step 1500: 150.989502
# Minibatch accuracy: 82.0%
# Validation accuracy: 80.5%
# Minibatch loss at step 2000: 266.244965
# Minibatch accuracy: 78.1%
# Validation accuracy: 80.7%
# Minibatch loss at step 2500: 262.755493
# Minibatch accuracy: 71.9%
# Validation accuracy: 81.0%
# Minibatch loss at step 3000: 157.678238
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Test accuracy: 88.3%
# >> with keep prob of 0.9
# >> with learning rate  0.0009000000000000001
# Initialized
# Minibatch loss at step 0: 4402.717773
# Minibatch accuracy: 12.5%
# Validation accuracy: 13.4%
# Minibatch loss at step 500: 587.234802
# Minibatch accuracy: 70.3%
# Validation accuracy: 79.2%
# Minibatch loss at step 1000: 302.010803
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.2%
# Minibatch loss at step 1500: 161.728607
# Minibatch accuracy: 83.6%
# Validation accuracy: 80.7%
# Minibatch loss at step 2000: 183.444656
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.1%
# Minibatch loss at step 2500: 168.799713
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.8%
# Minibatch loss at step 3000: 137.285461
# Minibatch accuracy: 77.3%
# Validation accuracy: 80.8%
# Test accuracy: 88.2%
# >> with keep prob of 0.9
# >> with learning rate  0.0001
# Initialized
# Minibatch loss at step 0: 5858.713867
# Minibatch accuracy: 8.6%
# Validation accuracy: 7.9%
# Minibatch loss at step 500: 1249.024658
# Minibatch accuracy: 57.8%
# Validation accuracy: 69.6%
# Minibatch loss at step 1000: 849.988098
# Minibatch accuracy: 61.7%
# Validation accuracy: 74.1%
# Minibatch loss at step 1500: 393.564941
# Minibatch accuracy: 79.7%
# Validation accuracy: 76.1%
# Minibatch loss at step 2000: 726.841919
# Minibatch accuracy: 71.9%
# Validation accuracy: 77.1%
# Minibatch loss at step 2500: 636.703003
# Minibatch accuracy: 71.1%
# Validation accuracy: 77.8%
# Minibatch loss at step 3000: 369.782837
# Minibatch accuracy: 78.1%
# Validation accuracy: 78.3%
# Test accuracy: 86.0%
# >> with keep prob of 0.9
# >> with learning rate  0.0002
# Initialized
# Minibatch loss at step 0: 6129.732422
# Minibatch accuracy: 13.3%
# Validation accuracy: 11.2%
# Minibatch loss at step 500: 922.738464
# Minibatch accuracy: 62.5%
# Validation accuracy: 74.6%
# Minibatch loss at step 1000: 682.985596
# Minibatch accuracy: 67.2%
# Validation accuracy: 77.1%
# Minibatch loss at step 1500: 268.098724
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.5%
# Minibatch loss at step 2000: 557.804321
# Minibatch accuracy: 71.9%
# Validation accuracy: 79.1%
# Minibatch loss at step 2500: 633.043945
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 3000: 427.904541
# Minibatch accuracy: 75.8%
# Validation accuracy: 80.0%
# Test accuracy: 87.4%
# >> with keep prob of 0.9
# >> with learning rate  0.00030000000000000003
# Initialized
# Minibatch loss at step 0: 5894.063965
# Minibatch accuracy: 13.3%
# Validation accuracy: 9.8%
# Minibatch loss at step 500: 710.513000
# Minibatch accuracy: 71.9%
# Validation accuracy: 75.8%
# Minibatch loss at step 1000: 740.748779
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.2%
# Minibatch loss at step 1500: 213.154358
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.2%
# Minibatch loss at step 2000: 670.489990
# Minibatch accuracy: 72.7%
# Validation accuracy: 79.7%
# Minibatch loss at step 2500: 487.561584
# Minibatch accuracy: 71.1%
# Validation accuracy: 80.0%
# Minibatch loss at step 3000: 324.049286
# Minibatch accuracy: 73.4%
# Validation accuracy: 80.3%
# Test accuracy: 87.8%
# >> with keep prob of 0.9
# >> with learning rate  0.0004
# Initialized
# Minibatch loss at step 0: 6058.354980
# Minibatch accuracy: 10.2%
# Validation accuracy: 9.4%
# Minibatch loss at step 500: 946.697937
# Minibatch accuracy: 64.1%
# Validation accuracy: 76.7%
# Minibatch loss at step 1000: 571.989868
# Minibatch accuracy: 70.3%
# Validation accuracy: 78.8%
# Minibatch loss at step 1500: 316.120361
# Minibatch accuracy: 83.6%
# Validation accuracy: 79.5%
# Minibatch loss at step 2000: 363.337128
# Minibatch accuracy: 79.7%
# Validation accuracy: 80.2%
# Minibatch loss at step 2500: 470.300049
# Minibatch accuracy: 70.3%
# Validation accuracy: 80.3%
# Minibatch loss at step 3000: 294.520782
# Minibatch accuracy: 80.5%
# Validation accuracy: 80.5%
# Test accuracy: 88.2%
# >> with keep prob of 0.9
# >> with learning rate  0.0005
# Initialized
# Minibatch loss at step 0: 5131.238770
# Minibatch accuracy: 7.0%
# Validation accuracy: 11.1%
# Minibatch loss at step 500: 683.722412
# Minibatch accuracy: 68.0%
# Validation accuracy: 77.8%
# Minibatch loss at step 1000: 547.113770
# Minibatch accuracy: 69.5%
# Validation accuracy: 79.3%
# Minibatch loss at step 1500: 219.658875
# Minibatch accuracy: 84.4%
# Validation accuracy: 80.0%
# Minibatch loss at step 2000: 341.654449
# Minibatch accuracy: 78.9%
# Validation accuracy: 80.5%
# Minibatch loss at step 2500: 319.798126
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 3000: 193.681931
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.0%
# Test accuracy: 88.1%
# >> with keep prob of 0.9
# >> with learning rate  0.0006000000000000001
# Initialized
# Minibatch loss at step 0: 6436.067871
# Minibatch accuracy: 9.4%
# Validation accuracy: 8.5%
# Minibatch loss at step 500: 562.811157
# Minibatch accuracy: 71.1%
# Validation accuracy: 78.1%
# Minibatch loss at step 1000: 405.082062
# Minibatch accuracy: 71.9%
# Validation accuracy: 79.5%
# Minibatch loss at step 1500: 214.406982
# Minibatch accuracy: 79.7%
# Validation accuracy: 80.1%
# Minibatch loss at step 2000: 275.484406
# Minibatch accuracy: 75.8%
# Validation accuracy: 80.8%
# Minibatch loss at step 2500: 242.967239
# Minibatch accuracy: 76.6%
# Validation accuracy: 80.7%
# Minibatch loss at step 3000: 177.993210
# Minibatch accuracy: 78.9%
# Validation accuracy: 81.0%
# Test accuracy: 88.3%
# >> with keep prob of 0.9
# >> with learning rate  0.0007000000000000001
# Initialized
# Minibatch loss at step 0: 4597.146973
# Minibatch accuracy: 10.2%
# Validation accuracy: 10.4%
# Minibatch loss at step 500: 550.176636
# Minibatch accuracy: 72.7%
# Validation accuracy: 78.4%
# Minibatch loss at step 1000: 371.032776
# Minibatch accuracy: 74.2%
# Validation accuracy: 79.8%
# Minibatch loss at step 1500: 202.555008
# Minibatch accuracy: 85.2%
# Validation accuracy: 80.8%
# Minibatch loss at step 2000: 279.207733
# Minibatch accuracy: 79.7%
# Validation accuracy: 81.1%
# Minibatch loss at step 2500: 218.028931
# Minibatch accuracy: 73.4%
# Validation accuracy: 80.9%
# Minibatch loss at step 3000: 144.705872
# Minibatch accuracy: 76.6%
# Validation accuracy: 80.9%
# Test accuracy: 88.6%
# >> with keep prob of 0.9
# >> with learning rate  0.0008
# Initialized
# Minibatch loss at step 0: 5913.178223
# Minibatch accuracy: 3.9%
# Validation accuracy: 8.7%
# Minibatch loss at step 500: 687.216309
# Minibatch accuracy: 70.3%
# Validation accuracy: 79.4%
# Minibatch loss at step 1000: 342.149536
# Minibatch accuracy: 74.2%
# Validation accuracy: 80.6%
# Minibatch loss at step 1500: 184.764160
# Minibatch accuracy: 82.0%
# Validation accuracy: 81.1%
# Minibatch loss at step 2000: 231.830460
# Minibatch accuracy: 76.6%
# Validation accuracy: 81.2%
# Minibatch loss at step 2500: 222.484787
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.3%
# Minibatch loss at step 3000: 155.316208
# Minibatch accuracy: 75.8%
# Validation accuracy: 81.2%
# Test accuracy: 87.9%
# >> with keep prob of 0.9
# >> with learning rate  0.0009000000000000001
# Initialized
# Minibatch loss at step 0: 5004.067383
# Minibatch accuracy: 10.2%
# Validation accuracy: 12.9%
# Minibatch loss at step 500: 490.370667
# Minibatch accuracy: 71.1%
# Validation accuracy: 79.2%
# Minibatch loss at step 1000: 371.572968
# Minibatch accuracy: 71.1%
# Validation accuracy: 80.3%
# Minibatch loss at step 1500: 191.750977
# Minibatch accuracy: 83.6%
# Validation accuracy: 80.7%
# Minibatch loss at step 2000: 250.453552
# Minibatch accuracy: 76.6%
# Validation accuracy: 81.1%
# Minibatch loss at step 2500: 218.897110
# Minibatch accuracy: 74.2%
# Validation accuracy: 81.2%
# Minibatch loss at step 3000: 133.114609
# Minibatch accuracy: 77.3%
# Validation accuracy: 80.9%
# Test accuracy: 88.4%
# >> with keep prob of 1.0
# >> with learning rate  0.0001
# Initialized
# Minibatch loss at step 0: 5712.914062
# Minibatch accuracy: 7.8%
# Validation accuracy: 9.7%
# Minibatch loss at step 500: 754.090149
# Minibatch accuracy: 60.2%
# Validation accuracy: 65.2%
# Minibatch loss at step 1000: 614.372986
# Minibatch accuracy: 69.5%
# Validation accuracy: 70.0%
# Minibatch loss at step 1500: 280.915863
# Minibatch accuracy: 78.9%
# Validation accuracy: 72.0%
# Minibatch loss at step 2000: 485.508514
# Minibatch accuracy: 74.2%
# Validation accuracy: 73.1%
# Minibatch loss at step 2500: 456.068329
# Minibatch accuracy: 73.4%
# Validation accuracy: 74.3%
# Minibatch loss at step 3000: 455.901093
# Minibatch accuracy: 71.1%
# Validation accuracy: 74.7%
# Test accuracy: 82.6%
# >> with keep prob of 1.0
# >> with learning rate  0.0002
# Initialized
# Minibatch loss at step 0: 5741.387207
# Minibatch accuracy: 7.0%
# Validation accuracy: 8.5%
# Minibatch loss at step 500: 645.725891
# Minibatch accuracy: 69.5%
# Validation accuracy: 70.9%
# Minibatch loss at step 1000: 464.395996
# Minibatch accuracy: 74.2%
# Validation accuracy: 74.0%
# Minibatch loss at step 1500: 262.597595
# Minibatch accuracy: 84.4%
# Validation accuracy: 75.4%
# Minibatch loss at step 2000: 359.197205
# Minibatch accuracy: 76.6%
# Validation accuracy: 76.5%
# Minibatch loss at step 2500: 508.534607
# Minibatch accuracy: 71.9%
# Validation accuracy: 76.9%
# Minibatch loss at step 3000: 314.252747
# Minibatch accuracy: 76.6%
# Validation accuracy: 77.3%
# Test accuracy: 84.5%
# >> with keep prob of 1.0
# >> with learning rate  0.00030000000000000003
# Initialized
# Minibatch loss at step 0: 5441.751465
# Minibatch accuracy: 6.2%
# Validation accuracy: 6.8%
# Minibatch loss at step 500: 583.376221
# Minibatch accuracy: 69.5%
# Validation accuracy: 71.9%
# Minibatch loss at step 1000: 422.492401
# Minibatch accuracy: 71.9%
# Validation accuracy: 74.8%
# Minibatch loss at step 1500: 226.173737
# Minibatch accuracy: 83.6%
# Validation accuracy: 76.1%
# Minibatch loss at step 2000: 316.056671
# Minibatch accuracy: 78.9%
# Validation accuracy: 76.9%
# Minibatch loss at step 2500: 305.032990
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.4%
# Minibatch loss at step 3000: 215.160339
# Minibatch accuracy: 78.9%
# Validation accuracy: 77.9%
# Test accuracy: 85.3%
# >> with keep prob of 1.0
# >> with learning rate  0.0004
# Initialized
# Minibatch loss at step 0: 5008.636719
# Minibatch accuracy: 5.5%
# Validation accuracy: 9.6%
# Minibatch loss at step 500: 664.340637
# Minibatch accuracy: 71.1%
# Validation accuracy: 72.8%
# Minibatch loss at step 1000: 308.255310
# Minibatch accuracy: 75.8%
# Validation accuracy: 75.5%
# Minibatch loss at step 1500: 200.898529
# Minibatch accuracy: 84.4%
# Validation accuracy: 76.7%
# Minibatch loss at step 2000: 305.919647
# Minibatch accuracy: 77.3%
# Validation accuracy: 77.4%
# Minibatch loss at step 2500: 365.375671
# Minibatch accuracy: 77.3%
# Validation accuracy: 77.7%
# Minibatch loss at step 3000: 242.647263
# Minibatch accuracy: 78.9%
# Validation accuracy: 78.0%
# Test accuracy: 86.1%
# >> with keep prob of 1.0
# >> with learning rate  0.0005
# Initialized
# Minibatch loss at step 0: 4498.158691
# Minibatch accuracy: 11.7%
# Validation accuracy: 10.4%
# Minibatch loss at step 500: 467.947205
# Minibatch accuracy: 68.0%
# Validation accuracy: 74.1%
# Minibatch loss at step 1000: 335.721680
# Minibatch accuracy: 75.8%
# Validation accuracy: 76.6%
# Minibatch loss at step 1500: 227.674301
# Minibatch accuracy: 82.0%
# Validation accuracy: 77.7%
# Minibatch loss at step 2000: 236.887024
# Minibatch accuracy: 82.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 2500: 288.692932
# Minibatch accuracy: 73.4%
# Validation accuracy: 78.9%
# Minibatch loss at step 3000: 191.011780
# Minibatch accuracy: 80.5%
# Validation accuracy: 79.2%
# Test accuracy: 86.4%
# >> with keep prob of 1.0
# >> with learning rate  0.0006000000000000001
# Initialized
# Minibatch loss at step 0: 4851.591797
# Minibatch accuracy: 12.5%
# Validation accuracy: 12.9%
# Minibatch loss at step 500: 363.231598
# Minibatch accuracy: 73.4%
# Validation accuracy: 75.6%
# Minibatch loss at step 1000: 316.568939
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.2%
# Minibatch loss at step 1500: 178.069763
# Minibatch accuracy: 85.2%
# Validation accuracy: 78.4%
# Minibatch loss at step 2000: 293.923187
# Minibatch accuracy: 76.6%
# Validation accuracy: 79.0%
# Minibatch loss at step 2500: 296.060486
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.6%
# Minibatch loss at step 3000: 138.249603
# Minibatch accuracy: 82.8%
# Validation accuracy: 79.9%
# Test accuracy: 86.7%
# >> with keep prob of 1.0
# >> with learning rate  0.0007000000000000001
# Initialized
# Minibatch loss at step 0: 4806.327148
# Minibatch accuracy: 5.5%
# Validation accuracy: 8.6%
# Minibatch loss at step 500: 553.551697
# Minibatch accuracy: 71.1%
# Validation accuracy: 75.4%
# Minibatch loss at step 1000: 285.312958
# Minibatch accuracy: 78.9%
# Validation accuracy: 77.9%
# Minibatch loss at step 1500: 244.024445
# Minibatch accuracy: 82.8%
# Validation accuracy: 78.2%
# Minibatch loss at step 2000: 197.523605
# Minibatch accuracy: 80.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 2500: 270.141571
# Minibatch accuracy: 73.4%
# Validation accuracy: 79.2%
# Minibatch loss at step 3000: 157.321838
# Minibatch accuracy: 82.8%
# Validation accuracy: 79.3%
# Test accuracy: 86.9%
# >> with keep prob of 1.0
# >> with learning rate  0.0008
# Initialized
# Minibatch loss at step 0: 4206.537598
# Minibatch accuracy: 12.5%
# Validation accuracy: 14.1%
# Minibatch loss at step 500: 372.934418
# Minibatch accuracy: 78.9%
# Validation accuracy: 75.9%
# Minibatch loss at step 1000: 272.484314
# Minibatch accuracy: 73.4%
# Validation accuracy: 78.0%
# Minibatch loss at step 1500: 120.986656
# Minibatch accuracy: 89.8%
# Validation accuracy: 78.9%
# Minibatch loss at step 2000: 188.186905
# Minibatch accuracy: 82.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 2500: 280.066132
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.5%
# Minibatch loss at step 3000: 138.078247
# Minibatch accuracy: 84.4%
# Validation accuracy: 80.0%
# Test accuracy: 87.0%
# >> with keep prob of 1.0
# >> with learning rate  0.0009000000000000001
# Initialized
# Minibatch loss at step 0: 3584.509277
# Minibatch accuracy: 18.0%
# Validation accuracy: 14.2%
# Minibatch loss at step 500: 419.261932
# Minibatch accuracy: 71.1%
# Validation accuracy: 75.8%
# Minibatch loss at step 1000: 283.899170
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.9%
# Minibatch loss at step 1500: 147.407776
# Minibatch accuracy: 88.3%
# Validation accuracy: 78.5%
# Minibatch loss at step 2000: 194.731369
# Minibatch accuracy: 82.8%
# Validation accuracy: 79.3%
# Minibatch loss at step 2500: 196.301437
# Minibatch accuracy: 76.6%
# Validation accuracy: 79.8%
# Minibatch loss at step 3000: 164.017349
# Minibatch accuracy: 82.8%
# Validation accuracy: 79.8%
# Test accuracy: 87.2%
# {(0.5, 0.0001): 86.47, (0.5, 0.0002): 87.37, (0.5, 0.00030000000000000003): 87.74, (0.5, 0.0004): 87.89, (0.5, 0.0005): 87.7, (0.5, 0.0006000000000000001): 87.29, (0.5, 0.0007000000000000001): 87.41, (0.5, 0.0008): 87.63, (0.5, 0.0009000000000000001): 86.63, (0.6, 0.0001): 86.68, (0.6, 0.0002): 87.5, (0.6, 0.00030000000000000003): 87.84, (0.6, 0.0004): 88.18, (0.6, 0.0005): 88.02, (0.6, 0.0006000000000000001): 87.92, (0.6, 0.0007000000000000001): 87.81, (0.6, 0.0008): 88.01, (0.6, 0.0009000000000000001): 87.55, (0.7, 0.0001): 86.59, (0.7, 0.0002): 87.85, (0.7, 0.00030000000000000003): 88.26, (0.7, 0.0004): 88.06, (0.7, 0.0005): 87.87, (0.7, 0.0006000000000000001): 88.3, (0.7, 0.0007000000000000001): 88.59, (0.7, 0.0008): 88.27, (0.7, 0.0009000000000000001): 88.17, (0.9, 0.0001): 85.99, (0.9, 0.0002): 87.39, (0.9, 0.00030000000000000003): 87.77, (0.9, 0.0004): 88.18, (0.9, 0.0005): 88.08, (0.9, 0.0006000000000000001): 88.29, (0.9, 0.0007000000000000001): 88.56, (0.9, 0.0008): 87.93, (0.9, 0.0009000000000000001): 88.37, (1.0, 0.0001): 82.6, (1.0, 0.0002): 84.55, (1.0, 0.00030000000000000003): 85.35, (1.0, 0.0004): 86.07, (1.0, 0.0005): 86.4, (1.0, 0.0006000000000000001): 86.66, (1.0, 0.0007000000000000001): 86.86, (1.0, 0.0008): 87.01, (1.0, 0.0009000000000000001): 87.2}

# %% [markdown]
# ### trying 2 NN with different loss function

# %%
batch_size = 128
beta = 0.001

hidden_nodes1 = 1024
hidden_nodes2 = 512

graph = tf.Graph()
with graph.as_default():

    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # new hidden layer 1
    
    hidden_weights = tf.Variable( tf.truncated_normal([image_size * image_size, hidden_nodes1]) )
    hidden_biases = tf.Variable( tf.zeros([hidden_nodes1]))
    hidden_layer = tf.nn.relu( tf.matmul( tf_train_dataset, hidden_weights) + hidden_biases)
    
    # add dropout on hidden layer
    keep_prob = tf.placeholder("float")
    hidden_layer_drop = tf.nn.dropout(hidden_layer, keep_prob)
    
    # new hidden layer 2
    hidden_weights2 = tf.Variable( tf.truncated_normal([hidden_nodes1, hidden_nodes2]) )
    hidden_biases2 = tf.Variable( tf.zeros([hidden_nodes2]))
    hidden_layer2 = tf.nn.relu( tf.matmul( hidden_layer_drop, hidden_weights2) + hidden_biases2)
    
    # add dropout on hidden layer
    hidden_layer_drop2 = tf.nn.dropout(hidden_layer2, keep_prob)
    
    # Variables.
    weights = tf.Variable( tf.truncated_normal([hidden_nodes2, num_labels])) 
    biases = tf.Variable(tf.zeros([num_labels]))

    # Training computation.
    logits = tf.matmul(hidden_layer_drop2, weights) + biases
    
    loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels) )
    loss = tf.reduce_mean( loss + beta * ( tf.nn.l2_loss(weights) + tf.nn.l2_loss(hidden_weights) + tf.nn.l2_loss(hidden_weights2) ))

    # Optimizer.
    global_step = tf.Variable(0)  # count the number of steps taken.
    learnr = tf.placeholder("float")
    learning_rate = tf.train.exponential_decay(learnr, global_step, 100000, 0.95, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step= global_step)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)    
    
    valid_relu1 = tf.nn.relu(  tf.matmul(tf_valid_dataset, hidden_weights) + hidden_biases)    
    valid_relu2 = tf.nn.relu(  tf.matmul(valid_relu1, hidden_weights2) + hidden_biases2)    
    
    valid_prediction = tf.nn.softmax( tf.matmul(valid_relu2, weights) + biases) 
    
    test_relu1 = tf.nn.relu( tf.matmul( tf_test_dataset, hidden_weights) + hidden_biases)
    test_relu2 = tf.nn.relu( tf.matmul( test_relu1, hidden_weights2) + hidden_biases2)   
    
    test_prediction = tf.nn.softmax(tf.matmul(test_relu2, weights) + biases)

# %% [markdown]
# ### trying NN with 5 layers

# %%
batch_size = 128
beta = 0.001

hidden_nodes1 = 1024
hidden_nodes2 = 512
hidden_nodes3 = 256
hidden_nodes4 = 128
hidden_nodes5 = 64

graph = tf.Graph()
with graph.as_default():

    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # new hidden layer 1
    
    hidden_weights = tf.Variable( tf.truncated_normal([image_size * image_size, hidden_nodes1]) )
    hidden_biases = tf.Variable( tf.zeros([hidden_nodes1]))
    hidden_layer = tf.nn.relu( tf.matmul( tf_train_dataset, hidden_weights) + hidden_biases)
    
    # add dropout on hidden layer
    keep_prob = tf.placeholder("float")
    hidden_layer_drop = tf.nn.dropout(hidden_layer, keep_prob)
    
    # new hidden layer 2
    hidden_weights2 = tf.Variable( tf.truncated_normal([hidden_nodes1, hidden_nodes2]) )
    hidden_biases2 = tf.Variable( tf.zeros([hidden_nodes2]))
    hidden_layer2 = tf.nn.relu( tf.matmul( hidden_layer_drop, hidden_weights2) + hidden_biases2)
    
    # add dropout on hidden layer 2
    hidden_layer_drop2 = tf.nn.dropout(hidden_layer2, keep_prob)
    
    # new hidden layer 3
    hidden_weights3 = tf.Variable( tf.truncated_normal([hidden_nodes2, hidden_nodes3]) )
    hidden_biases3 = tf.Variable( tf.zeros([hidden_nodes3]))
    hidden_layer3 = tf.nn.relu( tf.matmul( hidden_layer_drop2, hidden_weights3) + hidden_biases3)
    
    # add dropout on hidden layer 3
    hidden_layer_drop3 = tf.nn.dropout(hidden_layer3, keep_prob)
    
    # new hidden layer 4
    hidden_weights4 = tf.Variable( tf.truncated_normal([hidden_nodes3, hidden_nodes4]) )
    hidden_biases4 = tf.Variable( tf.zeros([hidden_nodes4]))
    hidden_layer4 = tf.nn.relu( tf.matmul( hidden_layer_drop3, hidden_weights4) + hidden_biases4)
    
    # add dropout on hidden layer 4
    hidden_layer_drop4 = tf.nn.dropout(hidden_layer4, keep_prob)
    
    # new hidden layer 5
    hidden_weights5 = tf.Variable( tf.truncated_normal([hidden_nodes4, hidden_nodes5]) )
    hidden_biases5 = tf.Variable( tf.zeros([hidden_nodes5]))
    hidden_layer5 = tf.nn.relu( tf.matmul( hidden_layer_drop4, hidden_weights5) + hidden_biases5)
    
    # add dropout on hidden layer 5
    hidden_layer_drop5 = tf.nn.dropout(hidden_layer5, keep_prob)
    
    # Variables.
    weights = tf.Variable( tf.truncated_normal([hidden_nodes5, num_labels])) 
    biases = tf.Variable(tf.zeros([num_labels]))

    # Training computation.
    logits = tf.matmul(hidden_layer_drop5, weights) + biases
    
    loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels) )
    loss = tf.reduce_mean( loss + beta * tf.nn.l2_loss(weights) )

    # Optimizer.
    global_step = tf.Variable(0)  # count the number of steps taken.
    learnr = tf.placeholder("float")
    learning_rate = tf.train.exponential_decay(learnr, global_step, 100000, 0.95, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step= global_step)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)    
    
    valid_relu1 = tf.nn.relu(  tf.matmul(tf_valid_dataset, hidden_weights) + hidden_biases)    
    valid_relu2 = tf.nn.relu(  tf.matmul(valid_relu1, hidden_weights2) + hidden_biases2)  
    valid_relu3 = tf.nn.relu(  tf.matmul(valid_relu2, hidden_weights3) + hidden_biases3)   
    valid_relu4 = tf.nn.relu(  tf.matmul(valid_relu3, hidden_weights4) + hidden_biases4)
    valid_relu5 = tf.nn.relu(  tf.matmul(valid_relu4, hidden_weights5) + hidden_biases5)   
    
    valid_prediction = tf.nn.softmax( tf.matmul(valid_relu5, weights) + biases) 
    
    test_relu1 = tf.nn.relu( tf.matmul( tf_test_dataset, hidden_weights) + hidden_biases)
    test_relu2 = tf.nn.relu( tf.matmul( test_relu1, hidden_weights2) + hidden_biases2)   
    test_relu3 = tf.nn.relu( tf.matmul( test_relu2, hidden_weights3) + hidden_biases3)  
    test_relu4 = tf.nn.relu( tf.matmul( test_relu3, hidden_weights4) + hidden_biases4)   
    test_relu5 = tf.nn.relu( tf.matmul( test_relu4, hidden_weights5) + hidden_biases5)  
    
    test_prediction = tf.nn.softmax(tf.matmul(test_relu5, weights) + biases)
